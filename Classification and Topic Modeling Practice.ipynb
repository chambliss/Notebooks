# %%
import pandas as pd
import numpy as np
import os
from sklearn.feature_extraction.text import *
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %%
#filename_list = os.listdir()[0:49]

# Reduce to 25 files because 50 was too memory-intensive
filename_list = os.listdir()[0:24]

# %%
# Just making sure these file names are correct:
filename_list[0:5]

# Looks good!
# Out:
# ['0301116', '0304232', '0303017', '0303225', '0302131']

# %% [markdown]
# Now we can read in all 50 files from the `filename_list`.

# %%
corpus = []

for i in range(len(filename_list)):
    
    filename = filename_list[i]
    
    with open(filename, 'rb') as file:
        for line in file:
            line = line.strip()
            corpus.append(line)

# %%
len(corpus)
# Out:
# 33780

# %% [markdown]
# Is this a reasonable number of lines in our corpus? As a sanity check of whether this length makes sense, we can repeat the reading-in-and-appending process with just one file for comparison:

# %%
corpus = []

with open('0301180', 'rb') as file:
        for line in file:
            line = line.strip()
            corpus.append(line)

# %% [markdown]
# (We use `'rb'` here because opening the file with the default mode `'r'` fails due to a `UnicodeDecodeError`. Note also that it is not necessary to call `file.close()` since using `with` closes the file automatically.)

# %%
len(corpus)
# Out:
# 1710

# %% [markdown]
# Great! This is clearly smaller than reading in the entire `filename_list`, so the process worked correctly. We'll go ahead and redo reading in the `filename_list` below.

# %%
corpus = []

for i in range(len(filename_list)):
    
    filename = filename_list[i]
    
    with open(filename, 'rb') as file:
        for line in file:
            line = line.strip()
            corpus.append(line)

# %% [markdown]
# Now we can turn our corpus into a matrix of TF-IDF features using `sklearn`'s `TfidfVectorizer()`.

# %%
vectorizer = TfidfVectorizer(decode_error='ignore', stop_words='english', max_df=0.9, max_features = 10000)

X = vectorizer.fit_transform(corpus)
X
# Out:
# <33780x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 124867 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Let's take a look at the vocabulary that was learned by the vectorizer.

# %%
vectorizer.vocabulary_
# Out:
# {'latex': 6010,
#  'file': 4576,
#  'paper': 6986,
#  'documentstyle': 3853,
#  'preprint': 7269,
#  'eqsecnum': 4246,
#  'aps': 2282,
#  'epsfig': 4197,
#  'revtex': 7920,
#  '12pt': 527,
#  'article': 2314,
#  'tightenlines': 9155,
#  'twocolumn': 9344,
#  'def': 3531,
#  'tt': 9314,
#  'backslash': 2532,
#  'bibtex': 2687,
#  'rm': 7977,
#  'sc': 8154,
#  'ib': 5304,
#  'tex': 9079,
#  'newcommand': 6703,
#  'cs': 3360,
#  'ch': 2949,
#  'beq': 2624,
#  'begin': 2597,
#  'equation': 4253,
#  'eeq': 4035,
#  'end': 4132,
#  'bdm': 2590,
#  'displaymath': 3777,
#  'edm': 4029,
#  'beqa': 2625,
#  'eqnarray': 4241,
#  'eeqa': 4036,
#  'beqab': 2626,
#  'eeqab': 4037,
#  'partial': 7008,
#  'dlr': 3835,
#  'stackrel': 8635,
#  'leftrightarrow': 6051,
#  'lra': 6237,
#  'ms': 6559,
#  'm_': 6255,
#  'symbolfootnote': 8936,
#  'renewcommand': 7814,
#  'thefootnote': 9107,
#  'fnsymbol': 4636,
#  'footnote': 4652,
#  'alphfootnote': 2131,
#  'setcounter': 8297,
#  'sevenrm': 8308,
#  'alph': 2120,
#  'theequation': 9105,
#  'arabic': 2285,
#  'section': 8238,
#  'nn': 6723,
#  'nonumber': 6745,
#  'makefnmark': 6297,
#  'hbox': 5129,
#  '0pt': 423,
#  'thefnmark': 9106,
#  'hss': 5255,
#  'original': 6914,
#  'slijedeci': 8471,
#  'blok': 2731,
#  'alfabetsko': 2108,
#  'subnumeriranje': 8748,
#  'visestrukim': 9660,
#  'formulama': 4678,
#  'upotreba': 9479,
#  'pocinje': 7157,
#  'se': 8222,
#  'sa': 8104,
#  'alpheqn': 2130,
#  'prekida': 7262,
#  'reseteqn': 7864,
#  'saveeqn': 8139,
#  'value': 9546,
#  'stepcounter': 8678,
#  'mbox': 6387,
#  'document': 3851,
#  'draft': 3895,
#  'flushright': 4629,
#  'nyu': 6805,
#  'th': 9092,
#  '02': 133,
#  '03': 302,
#  '11': 471,
#  '01': 66,
#  'title': 9170,
#  'gravity': 5006,
#  'induced': 5449,
#  'smooth': 8494,
#  'soliton': 8511,
#  'author': 2377,
#  'marko': 6332,
#  'kolanovi': 5904,
#  'mail': 6282,
#  'mk679': 6485,
#  'edu': 4031,
#  'address': 2032,
#  'center': 2935,
#  'cosmology': 3304,
#  'particle': 7028,
#  'physics': 7108,
#  'department': 3598,
#  'new': 6700,
#  'york': 9932,
#  'university': 9460,
#  'ny': 6804,
#  '10003': 432,
#  'date': 3458,
#  'today': 9183,
#  'maketitle': 6299,
#  'abstract': 1966,
#  'consider': 3195,
#  'finite': 4590,
#  'thickness': 9138,
#  'graviton': 5004,
#  'kinetic': 5856,
#  'term': 9069,
#  'coupled': 3320,
#  'bulk': 2830,
#  'scalar': 8157,
#  'develops': 3649,
#  'solitonic': 8512,
#  'vacuum': 9537,
#  'expectation': 4373,
#  'couplings': 3323,
#  'kaluza': 5796,
#  'klein': 5871,
#  'modes': 6503,
#  'localized': 6176,
#  'matter': 6378,
#  'suppressed': 8893,
#  'giving': 4919,
#  'rise': 7968,
#  'crossover': 3357,
#  'distance': 3788,
#  'r_c': 7596,
#  '4d': 1327,
#  '5d': 1464,
#  'behavior': 2603,
#  'viewed': 9644,
#  'brane': 2799,
#  'regularization': 7756,
#  'model': 6499,
#  'dvali': 3958,
#  'gabadadze': 4799,
#  'porrati': 7191,
#  'narrowtext': 6647,
#  'newpage': 6705,
#  'introduction': 5598,
#  'worlds': 9820,
#  'theories': 9117,
#  'large': 5997,
#  'infinite': 5461,
#  'extra': 4420,
#  'dimensions': 3732,
#  'recently': 7701,
#  'provided': 7388,
#  'insight': 5507,
#  'number': 6790,
#  'problems': 7321,
#  'high': 5170,
#  'energy': 4143,
#  'possible': 7204,
#  'relations': 7776,
#  'models': 6501,
#  'emerge': 4098,
#  'fundamental': 4773,
#  'higher': 5171,
#  'dimensional': 3727,
#  'theory': 9119,
#  'described': 3622,
#  'terms': 9073,
#  'strings': 8713,
#  'realized': 7679,
#  'nature': 6656,
#  'valuable': 9545,
#  'testing': 9076,
#  'ground': 5024,
#  'ideas': 5318,
#  'time': 9163,
#  'believed': 2612,
#  'exist': 4357,
#  'compact': 3094,
#  'volume': 9667,
#  'problem': 7320,
#  'obtain': 6829,
#  'force': 4659,
#  'objects': 6819,
#  'located': 6180,
#  'work': 9814,
#  'cite': 3009,
#  'dgp': 3669,
#  'shown': 8365,
#  'newton': 6708,
#  'arises': 2299,
#  'action': 2010,
#  'label': 5960,
#  'int': 5523,
#  'xdy': 9866,
#  'sqrt': 8611,
#  'cal': 2864,
#  'dy': 3969,
#  'delta': 3572,
#  'r_': 7588,
#  'coordinate': 3270,
#  'dimension': 3726,
#  'curvature': 3373,
#  'g_': 4782,
#  'mn': 6490,
#  'metric': 6430,
#  'r_4': 7593,
#  'constructed': 3223,
#  'mu': 6565,
#  'nu': 6781,
#  'equiv': 4261,
#  'scale': 8160,
#  'm_p': 6265,
#  'characterizes': 2966,
#  'rigidity': 7961,
#  'order': 6902,
#  'correct': 3279,
#  'constant': 3212,
#  'taken': 9000,
#  'sim': 8399,
#  '10': 428,
#  '19': 629,
#  'gev': 4899,
#  'represented': 7839,
#  'function': 4768,
#  'zero': 9968,
#  'related': 7772,
#  'presented': 7276,
#  'studied': 8728,
#  'rele': 7787,
#  'ref': 7730,
#  'dgkn': 3667,
#  'low': 6224,
#  'ev': 4303,
#  'properties': 7370,
#  'cosmological': 3302,
#  'evolution': 4322,
#  'manifestations': 6308,
#  'astronomical': 2344,
#  'scales': 8165,
#  'string': 8711,
#  'realizations': 7677,
#  'examined': 4332,
#  'furt': 4776,
#  'dis': 3746,
#  'str': 8691,
#  'notes': 6761,
#  'study': 8730,
#  'similar': 8402,
#  'enhanced': 4151,
#  'sys': 8951,
#  'frac': 4700,
#  'chi': 2979,
#  'representing': 7840,
#  'tension': 9060,
#  'linearized': 6127,
#  'level': 6073,
#  'features': 4505,
#  'short': 8359,
#  'mediated': 6407,
#  'metastable': 6426,
#  'massless': 6349,
#  'resonance': 7872,
#  'width': 9781,
#  'distances': 3789,
#  'conclude': 3135,
#  'simpler': 8409,
#  'main': 6284,
#  'variation': 9567,
#  'strength': 8700,
#  'consequence': 3186,
#  'dilaton': 3720,
#  'like': 6099,
#  'coupling': 3322,
#  'scalara': 8158,
#  'exhibits': 4356,
#  'vev': 9631,
#  'neglect': 6678,
#  'gravitational': 5000,
#  'effect': 4040,
#  'equivalent': 4263,
#  'fine': 4589,
#  'tunning': 9325,
#  'spectrum': 8571,
#  'lagrangian': 5976,
#  'results': 7898,
#  'applicable': 2257,
#  'gauge': 4834,
#  'field': 4554,
#  'investigate': 5613,
#  'suppression': 8895,
#  'kk': 5864,
#  'tunneling': 9324,
#  'potential': 7211,
#  'barrier': 2552,
#  'contrary': 3247,
#  'kiri': 5858,
#  'different': 3701,
#  'scheme': 8177,
#  'considered': 3200,
#  'appendix': 2252,
#  'outline': 6938,
#  'procedure': 7323,
#  'finding': 4586,
#  'fermionic': 4527,
#  'fermion': 4526,
#  'varying': 9590,
#  'localization': 6174,
#  'non': 6733,
#  'homogeneous': 5217,
#  'general': 4860,
#  'let': 6067,
#  'phi': 7092,
#  'x_': 9850,
#  'solmod': 8514,
#  'partial_': 7009,
#  'fields': 4555,
#  'form': 4667,
#  'longrightarrow': 6199,
#  'chi_': 2980,
#  'cl': 3012,
#  'following': 4647,
#  'firstl': 4596,
#  'represent': 7836,
#  'approximation': 2278,
#  'decompose': 3511,
#  'sum_': 8799,
#  'phi_': 7093,
#  'sigma_': 8382,
#  'box': 2783,
#  'differential': 3702,
#  'wave': 9733,
#  'functions': 4771,
#  'ekv': 4068,
#  'taking': 9002,
#  'equations': 4254,
#  'eigenvalues': 4056,
#  'cross': 3354,
#  'multiplying': 6591,
#  'eigenfunctions': 4050,
#  'subtracting': 8774,
#  'integrating': 5541,
#  'length': 6058,
#  'orthogonality': 6922,
#  'relation': 7775,
#  'orth': 6920,
#  'alpha_': 2122,
#  'delta_': 3573,
#  'normalization': 6753,
#  'combining': 3076,
#  'negative': 6677,
#  'denominator': 3587,
#  'expression': 4404,
#  'positive': 7199,
#  'means': 6396,
#  'ghosts': 4904,
#  'tachions': 8986,
#  'ghost': 4903,
#  'effective': 4041,
#  'obtained': 6831,
#  'introduce': 5594,
#  'additional': 2029,
#  'charge': 2968,
#  'density': 3595,
#  'psi': 7404,
#  'rho': 7933,
#  'centered': 2936,
#  'coefficient': 3056,
#  'determined': 3642,
#  'profile': 7342,
#  'average': 2388,
#  'convo': 3268,
#  'tilde': 9158,
#  'reads': 7670,
#  'efac': 4038,
#  'left': 6048,
#  'right': 7958,
#  'mode': 6497,
#  'normalizable': 6752,
#  'choices': 2992,
#  'integral': 5535,
#  'single': 8430,
#  'continuum': 3239,
#  'nonzero': 6747,
#  'pm': 7153,
#  'infty': 5473,
#  'feature': 4504,
#  'distinguishes': 3796,
#  'cases': 2905,
#  'quasi': 7553,
#  'determine': 3641,
#  'specify': 8564,
#  'better': 2668,
#  'understand': 9416,
#  'connection': 3182,
#  'shape': 8326,
#  'useful': 9491,
#  'transform': 9243,
#  'schroedinger': 8192,
#  'schro': 8189,
#  'phi_m': 7098,
#  'quad': 7529,
#  'localizing': 6178,
#  'locpo': 6182,
#  'behave': 2601,
#  'attractive': 2367,
#  'repulsive': 7848,
#  'depends': 3605,
#  'balance': 2540,
#  'magnitude': 6277,
#  'second': 8235,
#  'derivative': 3614,
#  'subsection': 8753,
#  '2a': 1000,
#  'lead': 6032,
#  'excitations': 4342,
#  'example': 4334,
#  'gaussian': 4846,
#  'determines': 3643,
#  'tower': 9213,
#  'masses': 6344,
#  'integer': 5532,
#  'used': 9490,
#  'dv': 3956,
#  'repeat': 7825,
#  'use': 9489,
#  'starting': 8649,
#  'point': 7162,
#  'investigation': 5616,
#  'simple': 8407,
#  'harmonic': 5108,
#  'oscillator': 6931,
#  'shifted': 8347,
#  'vanishes': 9554,
#  'sho': 8355,
#  '2y': 1061,
#  'normalized': 6754,
#  'wfho': 9767,
#  'pi': 7111,
#  'ya': 9909,
#  'h_': 5071,
#  'goes': 4946,
#  'spho': 8584,
#  '2n': 1038,
#  'interaction': 5551,
#  'position': 7197,
#  'odd': 6843,
#  'vanishing': 9555,
#  'values': 9548,
#  'true': 9296,
#  'localize': 6175,
#  'reason': 7684,
#  'exponentially': 4396,
#  'decaying': 3506,
#  'doesn': 3857,
#  'naively': 6639,
#  'expect': 4372,
#  'pot2': 7210,
#  'consist': 3203,
#  'lzm': 6250,
#  'scattering': 8168,
#  'states': 8655,
#  'charges': 2971,
#  'q_1': 7464,
#  'q_2': 7467,
#  'exchange': 4337,
#  'change': 2955,
#  'law': 6017,
#  'establish': 4286,
#  'filed': 4577,
#  'governed': 4966,
#  'quadratically': 7531,
#  'powers': 7221,
#  'pc': 7044,
#  'gets': 4897,
#  'exp': 4365,
#  'dgpr': 3670,
#  '3e': 1198,
#  'ae': 2074,
#  'bigger': 2694,
#  'huge': 5263,
#  'potq': 7216,
#  'aa': 1944,
#  'fig': 4558,
#  'vspace': 9685,
#  '5mm': 1472,
#  'centerline': 2937,
#  'fig1': 4559,
#  'eps': 4192,
#  '10cm': 467,
#  'footnotesize': 4655,
#  'textbf': 9081,
#  'figure': 4563,
#  'solid': 8510,
#  'line': 6124,
#  'dashed': 3454,
#  'units': 9450,
#  'inverse': 5611,
#  '10000': 431,
#  'small': 8480,
#  'coincides': 3063,
#  'certain': 2941,
#  'square': 8614,
#  'cut': 3377,
#  'rapidly': 7636,
#  'drops': 3912,
#  'qualitatively': 7533,
#  'predict': 7252,
#  'lowest': 6229,
#  'bound': 2775,
#  'tunnel': 9323,
#  'interested': 5560,
#  'case': 2904,
#  'want': 9722,
#  'decay': 3505,
#  'mediate': 6406,
#  'mass': 6340,
#  'irrelevant': 5644,
#  'wkb': 9807,
#  'decw': 3524,
#  'gamma_': 4813,
#  'int_': 5524,
#  'y_1': 9903,
#  'y_2': 9904,
#  'classical': 3021,
#  'turning': 9330,
#  'points': 7165,
#  'condition': 3148,
#  'validity': 9544,
#  '2v': 1055,
#  'll': 6154,
#  'satisfied': 8133,
#  'evaluated': 4306,
#  'numerically': 6794,
#  'range': 7631,
#  'independent': 5437,
#  'behaves': 2602,
#  '488': 1311,
#  'power': 7219,
#  'negligible': 6682,
#  'numerical': 6793,
#  'error': 4277,
#  'zmdw': 9989,
#  '976': 1756,
#  'continuous': 3237,
#  'solving': 8524,
#  'explore': 4393,
#  'question': 7557,
#  'universality': 9454,
#  'types': 9355,
#  'profiles': 7343,
#  'universal': 9453,
#  'argued': 2293,
#  'fact': 4461,
#  'desirable': 3630,
#  'property': 7371,
#  'opens': 6886,
#  'possibility': 7203,
#  'spoiling': 8597,
#  'covariance': 3325,
#  'resulting': 7897,
#  'pointed': 7163,
#  'gia': 4906,
#  'rub': 8037,
#  'adopt': 2050,
#  'framework': 4723,
#  'violation': 9653,
#  'forms': 4675,
#  'standard': 8640,
#  'lower': 6226,
#  'cutoff': 3378,
#  'sm': 8479,
#  'particles': 7029,
#  'come': 3077,
#  'splitting': 8596,
#  'roughly': 8013,
#  'psi_': 7405,
#  'localizes': 6177,
#  'decoupled': 3517,
#  'return': 7904,
#  'solved': 8522,
#  'simplicity': 8412,
#  'evaluate': 4305,
#  'qualitative': 7532,
#  'follows': 4648,
#  'outside': 6940,
#  'plane': 7137,
#  'waves': 9740,
#  'frequency': 4736,
#  'inside': 5506,
#  'gaussians': 4847,
#  'dependent': 3603,
#  'height': 5139,
#  'approximately': 2276,
#  'approx': 2271,
#  'actual': 2015,
#  'dependence': 3602,
#  'fig2': 4560,
#  '12cm': 525,
#  'graph': 4984,
#  'positions': 7198,
#  'resonant': 7874,
#  'log': 6184,
#  'plot': 7147,
#  'multiplied': 6587,
#  'inset': 5505,
#  'peak': 7045,
#  'responsible': 7882,
#  'starts': 8650,
#  'decays': 3507,
#  'half': 5087,
#  'analysis': 2173,
#  'sampling': 8124,
#  'data': 3457,
#  'wi': 9774,
#  '997': 1851,
#  '005': 59,
#  'resonances': 7873,
#  'particular': 7030,
#  'unusual': 9477,
#  'happening': 5102,
#  'advocated': 2072,
#  '605': 1479,
#  'newtonian': 6709,
#  'given': 4916,
#  'mr': 6557,
#  'dm': 3836,
#  'supported': 8886,
#  'gg': 4901,
#  'lightest': 6097,
#  'contribute': 3249,
#  'unsuppressed': 9475,
#  'approximate': 2274,
#  'weak': 9748,
#  'mimicked': 6457,
#  'massive': 6347,
#  'gravitons': 5005,
#  'smaller': 8481,
#  'larger': 5999,
#  'reproduce': 7842,
#  'planck': 7136,
#  'rc': 7653,
#  'spin': 8585,
#  'gives': 4918,
#  'wrong': 9838,
#  'tensor': 9063,
#  'structure': 8723,
#  'propagator': 7366,
#  'vdvz': 9598,
#  'va': 9534,
#  'linear': 6125,
#  'effects': 4043,
#  'conjecture': 3168,
#  'mechanism': 6404,
#  'occurs': 6841,
#  'hand': 5094,
#  'currently': 3368,
#  'progress': 7347,
#  'pap5': 6984,
#  '1cm': 762,
#  'bf': 2669,
#  'acknowledgments': 2003,
#  'thank': 9100,
#  'alex': 2107,
#  'vilenkin': 9647,
#  'comments': 3082,
#  'grateful': 4994,
#  'discussion': 3765,
#  'encouraging': 4131,
#  'make': 6293,
#  'manuscript': 6320,
#  'public': 7433,
#  '2in': 1029,
#  'method': 6427,
#  'fermions': 4530,
#  'fer': 4520,
#  'xf': 9867,
#  'bar': 2547,
#  'dirac': 3740,
#  'algebra': 2112,
#  'gamma': 4812,
#  '2g': 1024,
#  'ab': 1946,
#  'choice': 2991,
#  'matrices': 6375,
#  'motion': 6536,
#  'ansatz': 2202,
#  'azap': 2407,
#  'g_m': 4793,
#  'xi_': 9870,
#  'h_m': 5081,
#  '2mm': 1036,
#  'spinors': 8590,
#  'spinor': 8588,
#  'soltocop': 8515,
#  'a_m': 1935,
#  'sin': 8424,
#  'b_m': 2519,
#  'cos': 3295,
#  'integrates': 5540,
#  'plugging': 7150,
#  'fdaf': 4502,
#  'f_': 4442,
#  'rlap': 7974,
#  'matrix': 6376,
#  'fourier': 4692,
#  'ft': 4754,
#  'dyf': 3970,
#  'clearly': 3028,
#  'reduced': 7723,
#  'diagonalization': 3680,
#  'hermitian': 5153,
#  'steps': 8679,
#  'write': 9834,
#  'schematically': 8176,
#  'diagon': 3678,
#  'dagger': 3435,
#  'lambda_': 5980,
#  'umu': 9394,
#  'rotated': 8007,
#  'sequentially': 8288,
#  'orthogonal': 6921,
#  'chosen': 2997,
#  'diagonalize': 3681,
#  'simplest': 8411,
#  'recover': 7709,
#  'ordinary': 6906,
#  'entry': 4177,
#  'diagonalizes': 3683,
#  'entries': 4175,
#  'diagonal': 3679,
#  'upper': 9480,
#  'row': 8016,
#  'zeroes': 9969,
#  'propagating': 7364,
#  'interesting': 5561,
#  'compare': 3099,
#  'inducing': 5451,
#  'dks': 3828,
#  'dick': 3688,
#  'references': 7733,
#  'bibitem': 2684,
#  'minkowski': 6471,
#  'space': 8543,
#  'phys': 7105,
#  'lett': 6068,
#  'b485': 2476,
#  '208': 863,
#  '2000': 781,
#  'hep': 5151,
#  '0005016': 18,
#  'gregory': 5016,
#  'rubakov': 8038,
#  'sibiryakov': 8376,
#  'opening': 6885,
#  'ultra': 9390,
#  'rev': 7908,
#  '84': 1610,
#  '5928': 1454,
#  'arxiv': 2316,
#  '0002072': 4,
#  'erlich': 4273,
#  'hollowood': 5206,
#  '5932': 1455,
#  '0002161': 7,
#  'kolanovic': 5905,
#  'nitti': 6717,
#  '64': 1501,
#  '2001': 786,
#  '084004': 390,
#  'ph': 7086,
#  '0102216': 73,
#  'citation': 3008,
#  '65': 1512,
#  '024031': 294,
#  '2002': 796,
#  '0106058': 89,
#  'delgado': 3568,
#  'lykken': 6248,
#  'pokorski': 7168,
#  'quiros': 7566,
#  'wagner': 9707,
#  'scenarios': 8172,
#  'tale': 9004,
#  'nucl': 6787,
#  '609': 1481,
#  '499': 1318,
#  '0102172': 72,
#  'deffayet': 3535,
#  '2000uy': 784,
#  '502': 1359,
#  '199': 707,
#  '0010186': 42,
#  '2001np': 792,
#  'acta': 2007,
#  'polon': 7180,
#  '32': 1090,
#  '3669': 1151,
#  '0110162': 107,
#  '2001pu': 793,
#  'accelerated': 1975,
#  'universe': 9455,
#  'leaking': 6036,
#  '044023': 358,
#  'astro': 2342,
#  '0105068': 82,
#  'kofinas': 5902,
#  '2001es': 788,
#  'ds': 3915,
#  'jhep': 5733,
#  '0108': 94,
#  '034': 345,
#  '0108013': 95,
#  'ponton': 7187,
#  'poppitz': 7189,
#  'casimir': 2906,
#  'radius': 7616,
#  'stabilization': 8631,
#  'orbifolds': 6901,
#  '0106': 85,
#  '019': 132,
#  '0105021': 81,
#  '124005': 510,
#  '0203136': 153,
#  'zamarias': 9959,
#  'black': 2725,
#  'hole': 5203,
#  'solutions': 8518,
#  '66': 1517,
#  '104028': 452,
#  '0208207': 227,
#  'middleton': 6450,
#  'siopsis': 8448,
#  'fat': 4492,
#  'branes': 2800,
#  '0210033': 249,
#  'discontinuity': 3756,
#  'vainshtein': 9539,
#  'continuity': 3236,
#  'versus': 9626,
#  'perturbative': 7079,
#  '044026': 359,
#  '0106001': 86,
#  'lue': 6242,
#  'cosmic': 3301,
#  'world': 9819,
#  '0111168': 113,
#  'gruzinov': 5032,
#  '0112246': 122,
#  '2002cp': 802,
#  'fully': 4767,
#  'covariant': 3326,
#  'van': 9550,
#  'dam': 3441,
#  'veltman': 9614,
#  'zakharov': 9957,
#  'absence': 1958,
#  'thereof': 9121,
#  '0203014': 150,
#  'zaldarriaga': 9958,
#  'moon': 6528,
#  '0212069': 275,
#  'starkman': 8645,
#  'leakage': 6035,
#  'probing': 7319,
#  'dark': 3450,
#  'using': 9495,
#  'local': 6172,
#  '0212083': 276,
#  'lowe': 6225,
#  'ramgoolam': 7625,
#  'einstein': 4064,
#  'hilbert': 5176,
#  '0107': 93,
#  '030': 303,
#  '0106067': 90,
#  'antoniadis': 2223,
#  'minasian': 6462,
#  'vanhove': 9552,
#  'calabi': 2865,
#  'yau': 9915,
#  'manifolds': 6312,
#  '648': 1509,
#  '69': 1529,
#  '2003': 840,
#  '0209030': 234,
#  'kiritsis': 5861,
#  'tetradis': 9078,
#  'tomaras': 9192,
#  '012': 123,
#  '0106050': 88,
#  'annihilation': 2196,
#  '0209217': 241,
#  'dubovsky': 3943,
#  'equivalence': 4262,
#  'principle': 7305,
#  '0212222': 284,
#  'add': 2022,
#  'arkani': 2302,
#  'hamed': 5090,
#  'dimopoulos': 3734,
#  'b429': 2465,
#  '263': 941,
#  '1998': 742,
#  'b436': 2466,
#  '257': 930,
#  'add2': 2023,
#  '0860': 399,
#  '1999': 750,
#  'yang': 9912,
#  'mills': 6456,
#  '22': 882,
#  '397': 1181,
#  '1970': 659,
#  'nonvanishing': 6746,
#  'gravitation': 4999,
#  '39': 1176,
#  '393': 1179,
#  '1972': 662,
#  'preparation': 7266,
#  'yu': 9935,
#  'smirnov': 8493,
#  'mcarthur': 6389,
#  'photon': 7102,
#  '535': 1404,
#  '295': 975,
#  '0203271': 162,
#  'documentclass': 3852,
#  'usepackage': 9492,
#  'graphics': 4988,
#  'color': 3070,
#  'amsmath': 2158,
#  'amssymb': 2159,
#  'da': 3429,
#  'dot': 3876,
#  'alpha': 2121,
#  'db': 3463,
#  'beta': 2662,
#  'dg': 3663,
#  'dd': 3475,
#  'lambda': 5979,
#  'sigma': 8381,
#  'varepsilon': 9561,
#  'tr': 9227,
#  'tau': 9019,
#  'omega': 6868,
#  'varrho': 9586,
#  'vt': 9686,
#  'vartheta': 9588,
#  'mc': 6388,
#  'mathcal': 6363,
#  'nabla': 6631,
#  'la': 5959,
#  'langle': 5990,
#  'ra': 7602,
#  'rangle': 7632,
#  'dag': 3434,
#  'wt': 9842,
#  'widetilde': 9780,
#  'tb': 9032,
#  'lr': 6236,
#  'numberwithin': 6792,
#  'setlength': 8299,
#  'textwidth': 9088,
#  '17cm': 615,
#  'textheight': 9082,
#  '22cm': 895,
#  'topmargin': 9198,
#  '0mm': 419,
#  'evensidemargin': 4311,
#  'oddsidemargin': 6846,
#  'parskip': 7007,
#  'medskipamount': 6409,
#  'baselinestretch': 2564,
#  'arraycolsep': 2310,
#  '2pt': 1043,
#  'bbbc': 2573,
#  'zop': 9991,
#  'bbbz': 2577,
#  'rop': 8003,
#  'bbbr': 2576,
#  'nop': 6748,
#  'bbbn': 2574,
#  'sf': 8314,
#  'bbbp': 2575,
#  'rr': 8022,
#  'thispagestyle': 9146,
#  'addtocounter': 2035,
#  'page': 6973,
#  '0304232': 341,
#  'aei': 2076,
#  ...}

# %% [markdown]
# As we can see, a -lot- of the vocabulary learned by the vectorizer has to do with LaTeX formatting for these papers.
#
# Just to show what the vectorizer is picking up, here's a glance of the first 25 lines of the first document:

# %%
corpus[1:25]
# Out:
# [b'',
#  b'%******************LATEX FILE OF THE PAPER***********************',
#  b'%',
#  b'%',
#  b'',
#  b'%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%',
#  b'\\documentstyle[preprint,eqsecnum,aps,epsfig]{revtex}',
#  b'%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%',
#  b'',
#  b'%\\documentstyle[12pt,epsfig]{article}',
#  b'',
#  b'%%%%%%%%%%%%%%%%',
#  b'\\tightenlines',
#  b'%%%%%%%%%%%%%%%',
#  b'',
#  b'',
#  b'%\\documentstyle[eqsecnum,twocolumn,aps]{revtex}',
#  b'\\def\\btt#1{{\\tt$\\backslash$#1}}',
#  b'\\def\\BibTeX{\\rm B{\\sc ib}\\TeX}',
#  b'',
#  b"\\newcommand{\\cs}{\\'{c}}",
#  b'\\newcommand{\\ch}{\\v{c}}',
#  b'\\newcommand{\\s}{\\v{s}}',
#  b'']

# %%
# Initialize NMF
nmf_model = NMF(n_components = 50, init = 'random')

# Create variable to make it easy to retrieve topics
idx_to_word = np.array(vectorizer.get_feature_names())

# %%
nmf_model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init='random', l1_ratio=0.0,
#   max_iter=200, n_components=50, random_state=None, shuffle=False,
#   solver='cd', tol=0.0001, verbose=0)

# %%
nmf_components = nmf_model.components_

# %%
for i, topic in enumerate(nmf_components):
    print("Topic {}: {}".format(i + 1, ",".join([str(x) for x in idx_to_word[topic.argsort()[-10:]]])))
# Out:
# Topic 1: stresstail,fluctuations,constitutive,tij,rho,relation,stress,energy,density,eq
# Topic 2: sin,qquad,infty,enthalpy,quad,ldots,sim,12,sqrt,frac
# Topic 3: mp,ll,cccc,clcr,eqno,ccl,rcl,quad,cc,array
# Topic 4: end,state,differential,motion,renewcommand,dirac,theequation,arabic,setcounter,equation
# Topic 5: kl,mathbb,ket,mbox,volume,half,rm,rangle,langle,newcommand
# Topic 6: tau_,phi_,oint,oscillations,qr,stackrel,ta,approx,quad,phi
# Topic 7: sbody12,rbrace,vec,lbrace,q_i,ab,half,exp,langle,left
# Topic 8: limit,matter,inflaton,gauge,spinor,theories,equations,strength,scalar,field
# Topic 9: s_,eq3,anfx,rw2,ea,ba,beqa,eeqa,newcommand,eqnarray
# Topic 10: open,super,effective,supersymmetric,yang,mills,superstring,gauge,string,theory
# Topic 11: iota,holomorphic,int_,bundle,supersymmetric,infty,qh,tr,cp,cal
# Topic 12: f_r,mu,forall,d_0,limr,int,eqq,psio,qr,ee
# Topic 13: currentone,branetransl,1stal,dw,dbi,ncsolution,id,solution,eqn,bea
# Topic 14: 10,fig,5cm,width,epsfig,case,eps,tb,footnote,figure
# Topic 15: epsilon,int,rho,sim,xi,kl,r_,i_,vec,delta
# Topic 16: q_,partial_,pm,3_0,ket,dagger,i_,_0,nn,hat
# Topic 17: dirac,theta,orthogonal,cp,bps,sec,fig,caption,beq,label
# Topic 18: energy,tails,hilbert,plane,string,dependent,wave,long,space,time
# Topic 19: f_,theta,gamma_i,pi_,q_,oint_,epsilon,p_,beta,alpha
# Topic 20: 9711200,href,abs,http,org,tt,arxiv,citation,hep,th
# Topic 21: su,background,infty,superstring,penrose,ads_5,qquad,limit,ads_3,times
# Topic 22: flushright,subequations,pmatrix,minipage,displaymath,abstract,thebibliography,document,center,end
# Topic 23: psi_c,d_0,i_l,i_r,da,dagger,partial_,qr,pm,psi
# Topic 24: e_,bigl,bigr,g_,equiv,w_,kl,a_,delta_,ij
# Topic 25: msc,_i,forall,sigma_,psi_,gamma_,omega,om,ket,eta
# Topic 26: subequations,cc,99,pmatrix,thebibliography,displaymath,abstract,document,center,begin
# Topic 27: reinhardt,lm4,following,witten,non,paper,example,model,footnote,cite
# Topic 28: cp,1998,2000,jhep,lett,rev,2002,nucl,phys,bf
# Topic 29: e_,mathcal,u_,partial_,f_,a_,sigma,g_,nu,mu
# Topic 30: boundary,dual,solutions,bound,state,d3,d5,d1,branes,brane
# Topic 31: subsection,case,non,action,lowest,equations,given,solution,terms,order
# Topic 32: int_,sqrt,l_3,al,sum_,exp,vareps,a_,int,pi
# Topic 33: q_1,nn,sim,theta_1,theta_2,sin,cos,wedge,vec,nonumber
# Topic 34: rangle_,p_,rbrace,q_i,nn,rangle,ab,nonu,eqno,right
# Topic 35: la,rm,nu,omega,qquad,pm,sqrt,f_,rho,lambda
# Topic 36: x_,nu_,sigma,text,alpha,overline,mu_,_n,q_,dot
# Topic 37: i_r,mbox,_1,cr,p_,pressure,partial_,vareps,enthalpy,bar
# Topic 38: rt2,gross,bern,phys,hs,textit,maldacena,witten,nw2,bibitem
# Topic 39: overline,kj,eqno,q_,oint_,matrices,beta,cc,epsilon,gamma
# Topic 40: bm,ra,bf,hbox,nolimits,rm,mathop,mbox,omega,def
# Topic 41: trace,eq7,eq9,symmetric,eq23,eq22,traceless,ldots,big,split
# Topic 42: charge,spectrum,non,state,boundary,charged,local,physical,bps,states
# Topic 43: sec,appendix,acknowledgments,consider,discuss,previous,model,conclusions,introduction,section
# Topic 44: end,ansatz2,heff,lorentztransf,bequation,sourceaction,boostedmetric,begin,eqn,align
# Topic 45: _i,ab,eqalign,cr,da,z_i,cdot,dagger,theta,partial
# Topic 46: omega,newcommand,overline,cdot,sqrt,i_,dagger,int,theta,tilde
# Topic 47: lambda,eq,tau,text,cc,nn,end,def,newcommand,eea
# Topic 48: ell_,model,mp,prime,cdot,ab,vec,pm,sigma,tau
# Topic 49: eqn,using,ansatz,subsection,eqs,pic,appendix,potential,fig,ref
# Topic 50: nabla,v_,a_,p_,m_,text,overline,rho_,varphi,chi

# %% [markdown]
# Sadly, these topics are not very coherent. We can spot a few that do seem to form a cohesive group, such as topic 14, which corresponds to figure-and-display-related LaTeX terms, and 23, which is similar. Quite a few individual topics seem to correspond to symbols and Greek letters. One question I have following this is why some of these would not simply be in the same category. It's possible that 50 components is too many, considering we've only read in 25 papers, and that we need to collapse the 50 NMF components into fewer (maybe, for example, 10).
#
# Let's try that next.

# %%
nmf_model_10 = NMF(n_components = 10, solver = 'mu')
nmf_model_10.fit(X)
nmf_components_10 = nmf_model_10.components_

# %%
for i, topic in enumerate(nmf_components_10):
    print("Topic {}: {}".format(i + 1, ",".join([str(x) for x in idx_to_word[topic.argsort()[-10:]]])))
# Out:
# Topic 1: displaymath,thebibliography,document,center,setcounter,figure,array,split,equation,end
# Topic 2: align,abstract,displaymath,document,center,eq,split,label,equation,begin
# Topic 3: sigma,tilde,ab,gamma,nonumber,nu,array,mu,left,right
# Topic 4: boostedmetric,sourceaction,minipage,eqn,thebibliography,figure,array,begin,end,align
# Topic 5: bf,href,abs,http,org,tt,arxiv,citation,hep,th
# Topic 6: gamma,sigma,cal,nu,p_,mu,bar,dot,beta,alpha
# Topic 7: partial,delta,mbox,gamma,lambda,omega,rm,bf,cal,def
# Topic 8: operator,a_,forall,int,limr,eqq,psio,qr,psi,ee
# Topic 9: pm,tilde,partial,eta,phi,bar,sqrt,psi,pi,frac
# Topic 10: center,thebibliography,bea,figure,newcommand,eea,array,begin,end,eqnarray

# %% [markdown]
# Hmm. Reducing the number of components (and experimenting with changing the solver) did not seem to help. Now our components are even less informative, as they are now overtaken completely by the LaTeX specifications.
#
# Let's turn to LDA and see if it can do any better here.

# %%
lda_model = LatentDirichletAllocation(max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)

lda_model.fit(X)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=50.0,
#              max_doc_update_iter=100, max_iter=5, mean_change_tol=0.001,
#              n_components=10, n_jobs=1, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
for i, topic in enumerate(lda_model.components_):
    print("Topic {}: {}".format(i + 1, ",".join([str(x) for x in idx_to_word[topic.argsort()[-20:]]])))
# Out:
# Topic 1: ref,following,section,spinors,possible,fluctuations,relations,does,limit,parameters,relation,topological,inflation,displaymath,condition,form,model,cite,boundary,bibitem
# Topic 2: orbifold,formula,study,introduction,nc,vskip,gamma_i,s_2,usepackage,symmetric,cq,24,5mm,vspace,1mm,hspace,l_3,group,bigskip,section
# Topic 3: delta,infty,theta,tau,sigma,gamma,nonumber,partial,chi,nu,psi,bar,cal,pi,tilde,phi,mu,left,right,frac
# Topic 4: invariant,let,wave,symmetry,scalar,background,potential,space,equations,supersymmetric,times,gauge,eq,string,time,branes,field,ref,theory,label
# Topic 5: tr,modes,psio,parameter,dx,terms,spectrum,small,deformation,su,corresponding,matter,ap,half,wedge,order,defined,density,charge,zero
# Topic 6: integral,mode,fig,spacetime,ea,scale,d_0,bea,dirac,algebra,eea,figure,vec,ee,array,align,eqnarray,begin,end,equation
# Topic 7: given,term,langle,consider,dimensions,theory,epsilon,omega,states,ket,state,energy,brane,non,overline,fields,dot,beta,def,alpha
# Topic 8: mpc,ac,displaystyle,newline,11,f_r,kj,graviphoton,caption,index,texttt,tt,document,phi_,arxiv,subsection,split,citation,hep,th
# Topic 9: spatial,evolution,oscillations,stackrel,corrections,new,2000,long,stress,lett,nucl,jhep,rm,rev,universe,2002,waves,supersymmetry,phys,bf
# Topic 10: need,eeq,pic,note,noindent,x_2,expression,bibitem,current,physics,spectral,geq,x_1,spinor,x_3,x_4,lb,def,footnote,varphi

# %% [markdown]
# Interesting! LDA gives us at least a few topics that are actually about physics, such as 4, 5, 7, and 8. The rest are still mostly LaTeX.
