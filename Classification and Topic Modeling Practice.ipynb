# %%
import pandas as pd
import numpy as np
import os
from sklearn.feature_extraction.text import *
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %%
filename_list = os.listdir()[0:300]

# %%
# Just making sure these file names are correct:
filename_list[0:5]

# Looks good!
# Out:
# ['0301116', '0304232', '0303017', '0303225', '0302131']

# %% [markdown]
# Now we can read in all the files from the `filename_list`.

# %%
corpus = []

for i in range(len(filename_list)):
    
    filename = filename_list[i]
    
    with open(filename, 'r', errors='ignore') as file:
            file_contents = file.read()
    
    # Add document to corpus
    corpus.append(file_contents)

# %%
len(corpus)
# Out:
# 300

# %% [markdown]
# We have exactly 300 documents to work with. Now we can turn our corpus into a matrix of TF-IDF features using `sklearn`'s `TfidfVectorizer()`.

# %%
vectorizer = TfidfVectorizer(decode_error='ignore', stop_words=latex_stopwords, max_df=0.6, max_features = 10000)

X = vectorizer.fit_transform(corpus)
X
# Out:
# <300x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 255164 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Let's take a look at the vocabulary that was learned by the vectorizer.

# %%
vectorizer.vocabulary_
# Out:
# {'cosmology': 2774,
#  'particle': 6959,
#  'department': 3121,
#  'york': 9905,
#  'ny': 6599,
#  'date': 2976,
#  'today': 9159,
#  'maketitle': 5935,
#  'thickness': 9102,
#  'graviton': 4507,
#  'kinetic': 5436,
#  'coupled': 2794,
#  'bulk': 2095,
#  'develops': 3187,
#  'solitonic': 8477,
#  'vacuum': 9483,
#  'expectation': 3865,
#  'couplings': 2797,
#  'kaluza': 5374,
#  'klein': 5449,
#  'modes': 6176,
#  'localized': 5790,
#  'matter': 6021,
#  'suppressed': 8858,
#  'giving': 4416,
#  'rise': 7955,
#  'distance': 3308,
#  'r_c': 7567,
#  '4d': 839,
#  '5d': 942,
#  'behavior': 1821,
#  'viewed': 9587,
#  'brane': 2046,
#  'regularization': 7751,
#  'dvali': 3457,
#  'gabadadze': 4280,
#  'porrati': 7199,
#  'newpage': 6431,
#  'worlds': 9778,
#  'infinite': 5032,
#  'extra': 3911,
#  'recently': 7681,
#  'provided': 7379,
#  'insight': 5070,
#  'problems': 7306,
#  'high': 4710,
#  'relations': 7767,
#  'models': 6174,
#  'emerge': 3608,
#  'fundamental': 4241,
#  'strings': 8679,
#  'realized': 7660,
#  'nature': 6380,
#  'valuable': 9488,
#  'testing': 9040,
#  'ground': 4527,
#  'ideas': 4888,
#  'believed': 1834,
#  'exist': 3851,
#  'compact': 2519,
#  'volume': 9614,
#  'force': 4140,
#  'objects': 6624,
#  'located': 5792,
#  'dgp': 3204,
#  'newton': 6435,
#  'arises': 1570,
#  'dy': 3467,
#  'r_': 7558,
#  'coordinate': 2740,
#  'dimension': 3252,
#  'curvature': 2869,
#  'mn': 6164,
#  'metric': 6097,
#  'r_4': 7563,
#  'constructed': 2676,
#  'scale': 8134,
#  'm_p': 5891,
#  'characterizes': 2315,
#  'correct': 2751,
#  'taken': 8957,
#  'sim': 8366,
#  '19': 286,
#  'gev': 4392,
#  'represented': 7832,
#  'presented': 7263,
#  'studied': 8691,
#  'phenomenology': 7057,
#  'low': 5834,
#  'ev': 3795,
#  'cosmological': 2772,
#  'evolution': 3813,
#  'scales': 8137,
#  'realizations': 7658,
#  'examined': 3823,
#  'dis': 3274,
#  'str': 8660,
#  'notes': 6539,
#  'enhanced': 3657,
#  'chi': 2337,
#  'representing': 7833,
#  'tension': 9027,
#  'less': 5684,
#  'linearized': 5734,
#  'level': 5691,
#  'features': 3994,
#  'short': 8318,
#  'metastable': 6093,
#  'massless': 5989,
#  'resonance': 7867,
#  'width': 9738,
#  'distances': 3309,
#  'five': 4079,
#  'conclude': 2580,
#  'through': 9127,
#  'simpler': 8373,
#  'captures': 2206,
#  'main': 5920,
#  'variation': 9510,
#  'strength': 8668,
#  'consequence': 2640,
#  'dilaton': 3247,
#  'coupling': 2796,
#  'exhibits': 3850,
#  'vev': 9572,
#  'neglect': 6399,
#  'gravitational': 4504,
#  'effect': 3536,
#  'fine': 4069,
#  'spectrum': 8536,
#  'lagrangian': 5568,
#  'applicable': 1532,
#  'investigate': 5170,
#  'suppression': 8859,
#  'kk': 5444,
#  'tunneling': 9296,
#  'barrier': 1762,
#  'contrary': 2711,
#  'scheme': 8149,
#  'appendix': 1529,
#  'outline': 6813,
#  'procedure': 7309,
#  'finding': 4066,
#  'fermionic': 4011,
#  'fermion': 4009,
#  'varying': 9535,
#  'localization': 5788,
#  'homogeneous': 4759,
#  'x_': 9817,
#  'partial_': 6936,
#  'longrightarrow': 5812,
#  'chi_': 2338,
#  'cl': 2393,
#  'represent': 7827,
#  'approximation': 1549,
#  'decompose': 3021,
#  'phi_': 7059,
#  'sigma_': 8342,
#  'box': 2024,
#  'differential': 3232,
#  'wave': 9689,
#  'eigenvalues': 3556,
#  'cross': 2836,
#  'multiplying': 6291,
#  'eigenfunctions': 3551,
#  'subtracting': 8742,
#  'integrating': 5106,
#  'length': 5675,
#  'orthogonality': 6783,
#  'alpha_': 1386,
#  'delta_': 3087,
#  'normalization': 6524,
#  'combining': 2494,
#  'negative': 6398,
#  'denominator': 3112,
#  'numerator': 6583,
#  'positive': 7203,
#  'ghosts': 4402,
#  'ghost': 4401,
#  'effective': 3537,
#  'introduce': 5151,
#  'additional': 1270,
#  'charge': 2318,
#  'density': 3119,
#  'centered': 2267,
#  'coefficient': 2453,
#  'profile': 7331,
#  'average': 1672,
#  'reads': 7652,
#  'mode': 6173,
#  'normalizable': 6523,
#  'choices': 2363,
#  'whose': 9729,
#  'integral': 5101,
#  'single': 8392,
#  'continuum': 2700,
#  'nonzero': 6512,
#  'feature': 3993,
#  'distinguishes': 3315,
#  'quasi': 7530,
#  'determine': 3179,
#  'specify': 8531,
#  'better': 1882,
#  'understand': 9381,
#  'connection': 2635,
#  'shape': 8288,
#  'transform': 9220,
#  'schroedinger': 8159,
#  'phi_m': 7071,
#  'quad': 7510,
#  'whether': 9726,
#  'behave': 1818,
#  'attractive': 1648,
#  'repulsive': 7840,
#  'depends': 3128,
#  'balance': 1745,
#  'magnitude': 5916,
#  'derivative': 3143,
#  'subsection': 8717,
#  '2a': 562,
#  'lead': 5641,
#  'excitations': 3837,
#  'gaussian': 4331,
#  'determines': 3180,
#  'tower': 9194,
#  'masses': 5987,
#  'integer': 5097,
#  'dv': 3453,
#  'repeat': 7814,
#  'starting': 8620,
#  'investigation': 5173,
#  'harmonic': 4632,
#  'oscillator': 6796,
#  'shifted': 8310,
#  'vanishes': 9493,
#  '2y': 622,
#  'normalized': 6527,
#  'ya': 9883,
#  'h_': 4579,
#  'goes': 4450,
#  '2n': 602,
#  'interaction': 5114,
#  'position': 7201,
#  'odd': 6658,
#  'vanishing': 9494,
#  'true': 9273,
#  'localize': 5789,
#  'reason': 7666,
#  'exponentially': 3890,
#  'decaying': 3015,
#  'doesn': 3354,
#  'could': 2781,
#  'naively': 6362,
#  'expect': 3864,
#  'consist': 2652,
#  'scattering': 8139,
#  'states': 8628,
#  'charges': 2320,
#  'q_1': 7467,
#  'q_2': 7469,
#  'exchange': 3832,
#  'change': 2298,
#  'law': 5622,
#  'establish': 3768,
#  'governed': 4468,
#  'much': 6268,
#  'quadratically': 7512,
#  'powers': 7222,
#  'pc': 6988,
#  'gets': 4390,
#  'exp': 3856,
#  '3e': 724,
#  'ae': 1313,
#  'bigger': 1916,
#  'huge': 4818,
#  'aa': 1186,
#  'fig': 4038,
#  'together': 9160,
#  'vspace': 9636,
#  '5mm': 948,
#  'centerline': 2269,
#  'fig1': 4039,
#  'eps': 3693,
#  '10cm': 174,
#  'footnotesize': 4135,
#  'textbf': 9045,
#  'figure': 4053,
#  'solid': 8476,
#  'line': 5732,
#  'dashed': 2973,
#  'units': 9406,
#  'inverse': 5164,
#  'coincides': 2463,
#  'certain': 2277,
#  'square': 8578,
#  'cut': 2874,
#  'rapidly': 7621,
#  'drops': 3421,
#  'qualitatively': 7515,
#  'predict': 7241,
#  'lowest': 5841,
#  'bound': 2017,
#  'interested': 5118,
#  'want': 9674,
#  'decay': 3014,
#  'mass': 5986,
#  'irrelevant': 5202,
#  'wkb': 9761,
#  'gamma_': 4292,
#  'int_': 5086,
#  'y_1': 9872,
#  'y_2': 9873,
#  'turning': 9300,
#  'points': 7173,
#  'validity': 9487,
#  '2v': 619,
#  'll': 5764,
#  'satisfied': 8112,
#  'everywhere': 3809,
#  'except': 3829,
#  'evaluated': 3798,
#  'numerically': 6585,
#  'range': 7612,
#  'behaves': 1820,
#  'power': 7220,
#  'negligible': 6402,
#  'numerical': 6584,
#  'error': 3759,
#  '976': 1085,
#  'continuous': 2698,
#  'solving': 8486,
#  'explore': 3886,
#  'question': 7538,
#  'universality': 9410,
#  'types': 9320,
#  'profiles': 7332,
#  'universal': 9409,
#  'sometimes': 8490,
#  'argued': 1565,
#  'desirable': 3162,
#  'property': 7360,
#  'opens': 6731,
#  'possibility': 7209,
#  'covariance': 2800,
#  'resulting': 7888,
#  'pointed': 7170,
#  'me': 6050,
#  'adopt': 1293,
#  'framework': 4189,
#  'violation': 9598,
#  'forms': 4152,
#  'lower': 5836,
#  'cutoff': 2875,
#  'sm': 8448,
#  'particles': 6960,
#  'come': 2495,
#  'splitting': 8561,
#  'roughly': 8004,
#  'itself': 5233,
#  'psi_': 7402,
#  'decoupled': 3031,
#  'return': 7895,
#  'solved': 8484,
#  'simplicity': 8375,
#  'evaluate': 3797,
#  'qualitative': 7514,
#  'outside': 6817,
#  'plane': 7136,
#  'waves': 9695,
#  'frequency': 4206,
#  'inside': 5069,
#  'dependent': 3126,
#  'height': 4669,
#  'approximately': 1547,
#  'approx': 1544,
#  'actual': 1258,
#  'dependence': 3124,
#  'fig2': 4040,
#  'graph': 4490,
#  'positions': 7202,
#  'log': 5798,
#  'plot': 7153,
#  'multiplied': 6286,
#  'responsible': 7874,
#  'starts': 8621,
#  'decays': 3016,
#  'half': 4609,
#  'data': 2975,
#  '005': 16,
#  'besides': 1862,
#  'resonances': 7868,
#  'until': 9427,
#  'nothing': 6540,
#  'unusual': 9429,
#  'advocated': 1312,
#  '605': 957,
#  'newtonian': 6436,
#  'mr': 6244,
#  'dm': 3348,
#  'supported': 8852,
#  'gg': 4395,
#  'lightest': 5715,
#  'contribute': 2714,
#  'approximate': 1545,
#  'weak': 9699,
#  'massive': 5988,
#  'gravitons': 4508,
#  'smaller': 8450,
#  'larger': 5604,
#  'reproduce': 7835,
#  'planck': 7134,
#  'rc': 7637,
#  'spin': 8548,
#  'wrong': 9797,
#  'tensor': 9030,
#  'propagator': 7356,
#  'va': 9478,
#  'effects': 3539,
#  'conjecture': 2623,
#  'mechanism': 6064,
#  'occurs': 6651,
#  'currently': 2865,
#  'progress': 7337,
#  '1cm': 370,
#  'acknowledgments': 1242,
#  'thank': 9065,
#  'alex': 1360,
#  'vilenkin': 9591,
#  'comments': 2502,
#  'am': 1413,
#  'grateful': 4498,
#  'discussion': 3293,
#  'encouraging': 3637,
#  'manuscript': 5955,
#  '2in': 589,
#  'method': 6094,
#  'fermions': 4012,
#  'xf': 9842,
#  'dirac': 3267,
#  'algebra': 1364,
#  '2g': 584,
#  'ab': 1188,
#  'choice': 2362,
#  'matrices': 6019,
#  'motion': 6220,
#  'ansatz': 1481,
#  'g_m': 4267,
#  'xi_': 9844,
#  'h_m': 4594,
#  '2mm': 599,
#  'spinors': 8553,
#  'spinor': 8551,
#  'a_m': 1177,
#  'sin': 8386,
#  'my': 6300,
#  'b_m': 1715,
#  'cos': 2766,
#  'although': 1409,
#  'plugging': 7156,
#  'f_': 3928,
#  'rlap': 7960,
#  'fourier': 4170,
#  'ft': 4220,
#  'clearly': 2410,
#  'reduced': 7706,
#  'diagonalization': 3211,
#  'hermitian': 4689,
#  'done': 3368,
#  'steps': 8648,
#  'schematically': 8148,
#  'dagger': 2960,
#  'lambda_': 5573,
#  'rotated': 7995,
#  'orthogonal': 6782,
#  'chosen': 2368,
#  'diagonalize': 3212,
#  'simplest': 8374,
#  'recover': 7690,
#  'ordinary': 6763,
#  'every': 3807,
#  'entry': 3681,
#  'go': 4446,
#  'entries': 3679,
#  'diagonal': 3210,
#  'upper': 9436,
#  'corner': 2748,
#  'column': 2483,
#  'row': 8009,
#  'zeroes': 9956,
#  'propagating': 7354,
#  'compare': 2528,
#  'references': 7720,
#  'minkowski': 6141,
#  '208': 440,
#  'gregory': 4518,
#  'rubakov': 8030,
#  'opening': 6729,
#  'ultra': 9353,
#  '84': 1046,
#  'arxiv': 1591,
#  'csaki': 2845,
#  'erlich': 3756,
#  'hollowood': 4748,
#  '64': 977,
#  'ph': 7049,
#  'citation': 2381,
#  '65': 985,
#  'lykken': 5866,
#  'pokorski': 7176,
#  'scenarios': 8142,
#  '609': 960,
#  'deffayet': 3047,
#  '199': 338,
#  'acta': 1251,
#  '32': 645,
#  'accelerated': 1214,
#  'universe': 9411,
#  'astro': 1618,
#  'ds': 3424,
#  'jhep': 5286,
#  '0108': 30,
#  '034': 117,
#  'casimir': 2225,
#  'radius': 7594,
#  'stabilization': 8594,
#  'six': 8411,
#  'orbifolds': 6755,
#  '0106': 26,
#  '019': 46,
#  'conductor': 2598,
#  'black': 1950,
#  'hole': 4744,
#  'braneworlds': 2050,
#  '66': 988,
#  'siopsis': 8402,
#  'fat': 3981,
#  'branes': 2048,
#  'discontinuity': 3282,
#  'vainshtein': 9485,
#  'nonperturbative': 6501,
#  'continuity': 2697,
#  'versus': 9566,
#  'perturbative': 7036,
#  'cosmic': 2771,
#  'world': 9775,
#  'fully': 4236,
#  'covariant': 2801,
#  'van': 9491,
#  'dam': 2962,
#  'veltman': 9552,
#  'zakharov': 9941,
#  'absence': 1204,
#  'thereof': 9082,
#  'probing': 7304,
#  'dark': 2970,
#  'local': 5784,
#  'lowe': 5835,
#  'ramgoolam': 7605,
#  'einstein': 3560,
#  'hilbert': 4714,
#  '0107': 28,
#  '030': 111,
#  'antoniadis': 1509,
#  'minasian': 6129,
#  'calabi': 2150,
#  'yau': 9888,
#  'manifolds': 5949,
#  '69': 1001,
#  '2003': 435,
#  'kiritsis': 5439,
#  'thick': 9101,
#  '012': 38,
#  'annihilation': 1474,
#  'dubovsky': 3444,
#  'equivalence': 3743,
#  'principle': 7292,
#  'add': 1265,
#  'arkani': 1572,
#  'hamed': 4615,
#  'dimopoulos': 3257,
#  '263': 511,
#  '257': 500,
#  'd59': 2916,
#  'yang': 9885,
#  'mills': 6123,
#  '22': 455,
#  '397': 712,
#  '1970': 314,
#  'nonvanishing': 6511,
#  'gravitation': 4503,
#  '39': 707,
#  '393': 709,
#  '1972': 316,
#  'preparation': 7254,
#  'yu': 9911,
#  'smirnov': 8459,
#  'photon': 7082,
#  '535': 894,
#  '295': 547,
#  'graphics': 4492,
#  'color': 2480,
#  'amsmath': 1436,
#  'amssymb': 1437,
#  'da': 2950,
#  'dot': 3376,
#  'db': 2984,
#  'dg': 3198,
#  'dd': 2995,
#  'varepsilon': 9499,
#  'tr': 9204,
#  'tau': 8971,
#  'varrho': 9531,
#  'vt': 9637,
#  'vartheta': 9533,
#  'mc': 6043,
#  'mathcal': 6002,
#  'nabla': 6345,
#  'la': 5540,
#  'langle': 5597,
#  'ra': 7579,
#  'rangle': 7614,
#  'dag': 2957,
#  'wt': 9801,
#  'widetilde': 9737,
#  'tb': 8986,
#  'lr': 5848,
#  'numberwithin': 6582,
#  'setlength': 8263,
#  'textwidth': 9055,
#  '17cm': 275,
#  'textheight': 9048,
#  '22cm': 465,
#  'topmargin': 9175,
#  '0mm': 158,
#  'evensidemargin': 3802,
#  'oddsidemargin': 6660,
#  'parskip': 6934,
#  'baselinestretch': 1773,
#  '2pt': 609,
#  'zop': 9987,
#  'sf': 8275,
#  'rr': 8019,
#  'thispagestyle': 9114,
#  'empty': 3624,
#  'addtocounter': 1276,
#  'page': 6882,
#  'aei': 1315,
#  '040': 125,
#  'vskip': 9634,
#  '5cm': 941,
#  'alternative': 1406,
#  'formulation': 4159,
#  'light': 5713,
#  'cone': 2599,
#  '0cm': 151,
#  'pankiewicz': 6898,
#  'max': 6027,
#  'institut': 5082,
#  'ur': 9439,
#  'germany': 4386,
#  'april': 1553,
#  'noindent': 6481,
#  'construct': 2675,
#  'manifestly': 5946,
#  'supersymmetric': 8842,
#  'extension': 3904,
#  'closed': 2419,
#  'cubic': 2855,
#  'vertex': 9569,
#  'dynamical': 3469,
#  'supercharges': 8806,
#  'built': 2094,
#  'bosonic': 2007,
#  'creation': 2826,
#  'oscillators': 6797,
#  'previously': 7280,
#  'formalism': 4145,
#  'formulations': 4160,
#  'physically': 7089,
#  'evidence': 3810,
#  'claim': 2395,
#  'discrete': 3288,
#  'zop_2': 9988,
#  'computing': 2567,
#  'shift': 8309,
#  'stringy': 8680,
#  'state': 8624,
#  'perturbation': 7034,
#  'verify': 9559,
#  'leading': 5642,
#  'planar': 7133,
#  'correction': 2753,
#  'anomalous': 1479,
#  'dual': 3436,
#  'operators': 6736,
#  'correctly': 2755,
#  'recovered': 7691,
#  'vfill': 9576,
#  'thesection': 9087,
#  'maximally': 6030,
#  'pp': 7223,
#  'blau': 1955,
#  'henceforth': 4680,
#  'referred': 7721,
#  'split': 8559,
#  '2dx': 576,
#  'dx': 3460,
#  'vec': 9545,
#  'bigl': 1919,
#  'bigr': 1921,
#  'f_5': 3934,
#  'wedge': 9704,
#  'provides': 7381,
#  'tractable': 9213,
#  'curved': 2872,
#  'background': 1729,
#  'flux': 4108,
#  'aspects': 1601,
#  'iib': 4916,
#  'green': 4515,
#  'schwarz': 8163,
#  'sheet': 8301,
#  'quadratic': 7511,
#  'hence': 4679,
#  'quantized': 7524,
#  'exactly': 3820,
#  'metsaev': 6099,
#  '2001bj': 396,
#  'consists': 2657,
#  'unique': 9398,
#  'excited': 3838,
#  '2002re': 420,
#  'qquad': 7505,
#  'momentum': 6195,
#  'aspect': 1600,
#  'penrose': 6999,
#  'gueven': 4560,
#  'ads_5': 1301,
#  'berenstein': 1850,
#  '2002jq': 414,
#  'allowed': 1378,
#  'derive': 3145,
#  'duality': 3438,
#  'double': 3382,
#  'scaling': 8138,
#  'su': 8697,
#  'super': 8801,
#  'sym': 8891,
#  'ads': 1296,
#  'cft': 2282,
#  'correspondence': 2763,
#  'maldacena': 5939,
#  'gubser': 4557,
#  '1998bc': 354,
#  'witten': 9757,
#  '1998qj': 356,
#  'latter': 5616,
#  'albeit': 1355,
#  'special': 8523,
#  'beyond': 1885,
#  'supergravity': 8821,
#  'solvability': 8481,
#  'induces': 5020,
#  'parameters': 6916,
#  '2_': 551,
#  'text': 9044,
#  'ym': 9903,
#  'g_2': 4254,
#  'conformal': 2613,
#  '_r': 1133,
#  'subgroup': 8705,
#  'singled': 8393,
#  'composite': 2556,
#  'bmn': 1968,
#  'difference': 3229,
#  'remains': 7786,
#  'duals': 3442,
#  'quantity': 7521,
#  'gross': 4524,
#  'santambrogio': 8107,
#  '2002sb': 422,
#  'genus': 4367,
#  'counting': 2791,
#  'kristjansen': 5494,
#  '2002bb': 403,
#  'constable': 2659,
#  'subsequently': 8721,
#  'side': 8337,
#  'novel': 6547,
#  'extensively': 3907,
#  'beisert': 1827,
#  '2002vq': 428,
#  'gursoy': 4567,
#  'janik': 5278,
#  '2002tn': 427,
#  'minahan': 6128,
#  '2002ff': 411,
#  'klose': 5453,
#  'interactions': 5115,
#  'correspond': 2762,
#  'sector': 8203,
#  'interacting': 5113,
#  'cf': 2279,
#  'eqref': 3730,
#  'flat': 4087,
#  'operator': 6734,
#  'difficulties': 3240,
#  'associated': 1608,
#  'transverse': 9242,
#  'coordinates': 2741,
#  'exploiting': 3884,
#  'ten': 9022,
#  'lorentz': 5822,
#  'broken': 2075,
#  'generator': 4362,
#  'involved': 5179,
#  'developed': 3184,
#  'mandelstam': 5942,
#  'cremmer': 2828,
#  'extended': 3901,
#  'superstring': 8840,
#  'successfully': 8748,
#  'generalized': 4352,
#  'spradlin': 8567,
#  '2002ar': 401,
#  '2002rv': 421,
#  '2002tg': 426,
#  'klebanov': 5448,
#  'he': 4660,
#  '2002zu': 434,
#  'open': 6728,
#  'chandrasekhar': 2296,
#  'stefanski': 8640,
#  'free': 4197,
#  'hamiltonian': 4617,
#  'requiring': 7847,
#  'basis': 1777,
#  'exponential': 3889,
#  'constraints': 2674,
#  'arise': 1569,
#  'requirement': 7844,
#  'superalgebra': 8802,
#  'anticommute': 1495,
#  'acquire': 1246,
#  'corrections': 2754,
#  'introducing': 5154,
#  'prefactors': 7249,
#  'polynomial': 7191,
#  'acting': 1252,
#  'functional': 4238,
#  'interpretation': 5132,
#  'perform': 7008,
#  'successful': 8747,
#  'test': 9037,
#  'roiban': 7978,
#  '2002xr': 433,
#  'reproduced': 7836,
#  'computation': 2561,
#  'gomis': 4457,
#  'huang': 4815,
#  'chu': 2371,
#  'lee': 5659,
#  'kiem': 5426,
#  'verlinde': 9562,
#  'zhou': 9979,
#  'vaman': 9490,
#  'pearson': 6994,
#  'bak': 1739,
#  'spite': 8558,
#  'success': 8746,
#  'puzzle': 7458,
#  'concerning': 2578,
#  'whereas': 9723,
#  'thereby': 9080,
#  'closely': 2420,
#  'followed': 4124,
#  'apparently': 1523,
#  'construction': 2678,
#  'called': 2172,
#  'initiated': 5057,
#  'lies': 5705,
#  'rather': 7626,
#  'axion': 1685,
#  'fluctuation': 4103,
#  'setup': 8268,
#  'mixture': 6155,
#  'trace': 9207,
#  'presence': 7261,
#  'breaks': 2059,
#  'exchanges': 3834,
#  'based': 1769,
#  'yields': 9900,
#  'respects': 7872,
#  'complete': 2539,
#  'attempt': 1641,
#  'resolve': 7861,
#  'strong': 8685,
#  'indications': 5013,
#  'em': 3601,
#  'preserve': 7268,
#  'symmetries': 8898,
#  'propose': 7365,
#  'organized': 6768,
#  'briefly': 2069,
#  'review': 7905,
#  'recall': 7673,
#  'compute': 2564,
#  'truncation': 9278,
#  'impurity': 4974,
#  'conserving': 2645,
#  'channel': 2302,
#  'several': 8270,
#  'appendices': 1528,
#  'included': 4980,
#  'summarize': 8787,
#  'notations': 6537,
#  'conventions': 2729,
#  'contain': 2684,
#  'details': 3171,
#  'derivation': 3141,
#  'expressions': 3898,
#  'constituents': 2664,
#  'i_r': 4869,
#  's_r': 8075,
#  'a_r': 1181,
#  'index': 5006,
#  'denotes': 3115,
#  's_': 8055,
#  'scriptsize': 8184,
#  'bos': 2004,
#  'int_0': 5087,
#  'prime': 7286,
#  'p_': 6846,
#  'x_r': 9839,
#  'alpha_r': 1398,
#  'collision': 2479,
#  'process': 7315,
#  'incoming': 4985,
#  'outgoing': 6812,
#  'expansions': 3863,
#  'p_r': 6864,
#  'xp': 9857,
#  'o_': 6607,
#  'canonical': 2199,
#  'quantization': 7522,
#  'usual': 9448,
#  'commutation': 2509,
#  'p_s': 6865,
#  'ij': 4918,
#  'd_': 2928,
#  'rs': 8021,
#  'nm': 6469,
#  'ferm': 4007,
#  'complex': 2546,
#  'chirality': 2357,
#  'pi_': 7093,
#  'symmetric': 8896,
#  'traceless': 9209,
#  'squares': 8580,
#  'conjugate': 2627,
#  'l_': 5517,
#  'anti': 1487,
#  'yield': 9898,
#  'rules': 8034,
#  'b_s': 1719,
#  'b_': 1702,
#  'normal': 6517,
#  'via': 9579,
#  'c_': 2123,
#  'break': 2056,
#  'representation': 7828,
#  'manifest': 5943,
#  'pmatrix': 7163,
#  'a_1': 1161,
#  'b_1': 1704,
#  'a_2': 1163,
#  'b_2': 1705,
#  'da_1': 2952,
#  'db_1': 2985,
#  'da_2': 2953,
#  'db_2': 2986,
#  'a_k': 1175,
#  'b_k': 1713,
#  'component': 2553,
#  'weyl': 9717,
#  'indices': 5014,
#  '_k': 1126,
#  'project': 7338,
#  'onto': 6721,
#  'energies': 3649,
#  'cancel': 2187,
#  'bosons': 2009,
#  'suppress': 8857,
#  'back': 1728,
#  'forth': 4162,
#  'formally': 4146,
#  'isometries': 5212,
#  'generated': 4357,
#  'angular': 1466,
#  'generators': 4363,
#  ...}

# %%
latex_stopwords = list(vectorizer.vocabulary_)[0:59]

# %% [markdown]
# Let's retrain with with the LaTeX stopwords collected from the initial vocabulary.

# %%
vectorizer = TfidfVectorizer(decode_error='ignore', stop_words=latex_stopwords, max_df=0.6, max_features = 10000)

X = vectorizer.fit_transform(corpus)
X

# %% [markdown]
# As we can see, a -lot- of the vocabulary learned by the vectorizer has to do with LaTeX formatting for these papers.

# %%
# Initialize NMF
nmf_model = NMF(n_components = 50, solver = 'mu')

# Create variable to make it easy to retrieve topics
idx_to_word = np.array(vectorizer.get_feature_names())

# %%
nmf_model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=50, random_state=None, shuffle=False, solver='mu',
#   tol=0.0001, verbose=0)

# %%
nmf_components = nmf_model.components_

# %%
for i, topic in enumerate(nmf_components):
    print("Topic {}: {}".format(i + 1, ", ".join([str(x) for x in idx_to_word[topic.argsort()[-10:]]])))
# Out:
# Topic 1: plane, ads, branes, supergravity, dilaton, background, boundary, wave, arxiv, citation
# Topic 2: deformed, e_n, epsilon_, ee, fuzzy, quad, 2k, partial_, phi_, hat
# Topic 3: cn, foot, kern, tr, arxiv, superpotential, eqalign, cr, lref, eqn
# Topic 4: lambda_4, citation, universe, hat, m_5, cosmological, kappa_5, branes, bulk, brane
# Topic 5: perp, gamma_1, tunneling, mid, cr, gamma_, cdot, sigma_, underline, vec
# Topic 6: flux, irp, planes, phantom, n_a, hline, brane, orientifold, d6, branes
# Topic 7: qquad, branes, horizon, dx, killing, metric, r_0, supergravity, ee, wedge
# Topic 8: inflationary, cosmology, cosmic, born, radiation, infeld, density, universe, rho_, inflation
# Topic 9: waldmann, sitter, mbw, multiplets, star, textbf, mathbb, emph, newblock, mathcal
# Topic 10: gl, ja, w_, superpotential, star, rd, bea, eea, cr, ee
# Topic 11: chiral, tr, la_a, su, superpotential, flavor, monopoles, 2n_f, n_c, n_f
# Topic 12: cr, quad, epsilon_, topological, eta, omega_, cd, sp, abcd, ab
# Topic 13: dot, displaystyle, dagger, rho_c, algebra, langevin, alignat, text, gamma_, big
# Topic 14: amplitude, state, open, inn, rolling, kink, reef, closed, t_, tachyon
# Topic 15: p_, varphi, noncommutative, k_, overline, b_, varphi_, f_, varepsilon, widetilde
# Topic 16: la, da_2, qquad, pp, p_, ra, wave, ad, bigr, bigl
# Topic 17: tau_2, ell_, r_, boldmath, entropy, feqr, beqr, eff, ell, tau
# Topic 18: tensionless, rebounce, em, kappa_5, align, arxiv, http, abs, href, org
# Topic 19: footnotesize, n_, thm, cdots, propagator, varepsilon, cobordism, v_, c_, prime
# Topic 20: magnetic, newblock, charge, core, 9cm, figure, cheshire, footnotesize, monopole, alice
# Topic 21: particle, wigner, kappa, he, ell, textbf, psfrag, his, jordan, textit
# Topic 22: entropy, frequencies, gr, schwarzschild, qc, area, quasinormal, holes, hole, black
# Topic 23: ddot, un, susy, si_, p_, si, xi, overline, la, dot
# Topic 24: ell, ijk, parent, h_, x_n, r_, nabla, kl, nabla_, ij
# Topic 25: array, x_j, pi_3, ads_2, 1n, noncommutative, x_i, sphere, fuzzy, eqno
# Topic 26: boldmath, box, otimes, array, psi_, phi_2, phi_, f_, chi, partial_
# Topic 27: operators, kappa, instanton, vac, impurities, co_, eqlabel, psfrag, bmn, eqref
# Topic 28: quantisation, iota, chart, hilbert, holomorphic, fibre, bundles, qh, bundle, cp
# Topic 29: armoni, citation, parent, none, domain, orientifold, daughter, gluodynamics, walls, wall
# Topic 30: t_e, euclidean, hole, phi_n, d_2, black, zbar, btz, horizon, r_
# Topic 31: mu_k, lambda_j, lambda_k, lambda_i, lambda_, schr, lambda_2, dinger, ast, hbar
# Topic 32: cosmological, rosen, spacetime, bbb, bigr, sitter, bigl, metric, ben, een
# Topic 33: pref, sp, mid, ze, dag, peq, gb, xf, ga, al
# Topic 34: text, varphi_, dfrac, align, effective, nd0, cjt, chi, emph, varphi
# Topic 35: picture, t_2, figure, xi, 20, sst, align, parent, aut, put
# Topic 36: lrcorner_, wedge, phi_3, psi_0, vphi, torsion, g_x, solitons, lrcorner, psi_3
# Topic 37: cdots, a_2, beta_m, p_2, tpt, erg, int_q, quad, 2n, p_1
# Topic 38: susy, brc, tht_1, kp, acl, tht_2, brkt, eql, vph, x_2
# Topic 39: x_3, superconductor, l_3, af, bfs, core, x_4, vortex, kappa, vortices
# Topic 40: coupling, branes, theta_d, quiver, x_, rr, orbifold, deconstruction, wilson, deconstructed
# Topic 41: cc, bea, eea, cb, hz, z_, bref, hj, gam, hi
# Topic 42: mills, module, q_k, torus, p_k, dd, vnu, partition, nu_a, noncommutative
# Topic 43: j_, 00, bref, pp, q_, wz, multicolumn, columncolor, definecolor, rgb
# Topic 44: snp, ttau, elliptic, li, ls, theta_1, sigma_, ep, ln, tfrac
# Topic 45: _0, z_, prod_, bm, plates, boundary, langle, rangle, xi, z_i
# Topic 46: bx, imath, nablab, ceq, ball, fermi, delta_b, psi_i, eqn2, n_i
# Topic 47: nc, chi, wh, wti, 3v, mo, qq, tht, su, ti
# Topic 48: lab, _f, e5, vp, prt_m, auxa, ghost, ket, u_f, rf
# Topic 49: c_, bigskip, noindent, qed, m_p, unruh, vert, vacuum, v_, ext
# Topic 50: mathop, updefault, rmdefault, mddefault, lb, e_6, setfigfont, nolimits, mathbb, ar

# %% [markdown]
# Sadly, these topics are not very informative. Quite a few individual topics seem to correspond to symbols and Greek letters. One question I have following this is why some of these would not simply be in the same category. It's possible that 50 components is too many, considering we've only read in 25 papers, and that we need to collapse the 50 NMF components into fewer (maybe, for example, 10).
#
# Let's try that next.

# %%
nmf_model_10 = NMF(n_components = 10, solver = 'mu')
nmf_model_10.fit(X)
nmf_components_10 = nmf_model_10.components_

# %%
for i, topic in enumerate(nmf_components_10):
    print("Topic {}: {}".format(i + 1, ", ".join([str(x) for x in idx_to_word[topic.argsort()[-10:]]])))
# Out:
# Topic 1: background, f_, r_, wave, boundary, citation, array, prime, partial_, tau
# Topic 2: ee, xi, sphere, 2k, phi_, quad, partial_, fuzzy, big, hat
# Topic 3: w_, foot, kern, tr, arxiv, eqalign, superpotential, cr, lref, eqn
# Topic 4: abs, org, kappa_5, href, hole, bulk, black, citation, arxiv, brane
# Topic 5: gamma_1, tunneling, mid, cr, sigma_, cdot, gamma_, big, underline, vec
# Topic 6: orbifold, su, twisted, supersymmetric, flux, d6, wall, orientifold, brane, branes
# Topic 7: eea, f_, al, xi, bea, ij, wedge, big, ab, ee
# Topic 8: ben, overline, density, een, tachyon, universe, rho_, varphi, inflation, dot
# Topic 9: t_, star, symplectic, bundle, cp, textbf, newblock, emph, mathbb, mathcal
# Topic 10: dag, superpotential, tr, prod_, nu_a, partition, ee, n_c, noncommutative, n_f

# %% [markdown]
# Reducing the number of components seemed to help a bit, but we still have multiple topics that are entirely LaTeX formatting specifications, and the physics-related topics still have some LaTeX artifacts.
#
# Let's turn to LDA and see if it can do any better here.

# %%
lda_model = LatentDirichletAllocation(max_iter = 5,
                                learning_method = 'online',
                                learning_offset = 50.,
                                random_state = 0)

lda_model.fit(X)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=50.0,
#              max_doc_update_iter=100, max_iter=5, mean_change_tol=0.001,
#              n_components=10, n_jobs=1, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
for i, topic in enumerate(lda_model.components_):
    print("Topic {}: {}".format(i + 1, ", ".join([str(x) for x in idx_to_word[topic.argsort()[-20:]]])))
# Out:
# Topic 1: bais, acla, l_s, kp, mathbf, dlt, l_, lmd, tau, defa, ui, brc, tht_2, der_2, acl, tht_1, eql, vph, brkt, x_2
# Topic 2: 566, 0212096, 643, psi_s, cohen, 35pt, http, 223, 575, eqn, m_r, big, dot, zf, character, arxiv, footnotesize, d1, wick, hat
# Topic 3: 608, hline, ze_d, imr, ee, families, fam, curve, disconnected, 0111, qr, rho_, bbs, l_3, 0truecm, cartan, treated, subset, suffices, brane
# Topic 4: bone, monopoles, gaugino, ben, eqn, h_o, quantization, eta, lorentz, chiral, xi, dot, monopole, ee, eventually, susy, ij, breaking, overline, alice
# Topic 5: mathcal, estimates, rg, wn, similarity, setup, line, schwarzschild, big, hi, cr, citation, gam, te, eqno, hline, qquad, vec, brane, hat
# Topic 6: r_, varphi, qquad, su, quad, dot, eqn, cr, f_, tau, arxiv, mathcal, big, branes, partial_, vec, citation, brane, ee, hat
# Topic 7: drastically, partitiondef, eac, 516, dot, located, qc, rindler, dec, motivations, hh, lj, amns, rb, dipolevaccond, numerical, phi_, sss, ze, vec
# Topic 8: citation, mathcal, impulse, representation, epsilon_, five, partition, topological, yau, xi, ads, supergravity, brane, boldmath, branes, varphi, prime, ab, ee, bm
# Topic 9: associated, inv, likewise, q_k, 1999a, nabla_j, si_3, products, arrive, 15em, vacuum, nieuwenhuizen, ij, ten, c_, su, people, mathop, gukov, widehat
# Topic 10: borcherds, inn, cr, ce, operator, vilenkin, superalgebra, sum_a, fi, path, dtd, thinlines, ee, holomorphic, emphasis, eqstar, ccr, ga, du, un

# %% [markdown]
# Yikes. LDA didn't do much better. These topics are not especially informative either...
