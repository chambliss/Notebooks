# %%
import pandas as pd
import numpy as np
import os
from sklearn.feature_extraction.text import *
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %%
filename_list = os.listdir()[0:500]

# %%
# Just making sure these file names are correct:
filename_list[0:5]

# Looks good!
# Out:
# ['0301116', '0304232', '0303017', '0303225', '0302131']

# %% [markdown]
# Now we can read in all the files from the `filename_list`.

# %%
corpus = []

for i in range(len(filename_list)):
    
    filename = filename_list[i]
    
    with open(filename, 'r', errors='ignore') as file:
            file_contents = file.read()
    
    # Add document to corpus
    corpus.append(file_contents)

# %%
len(corpus)
# Out:
# 500

# %% [markdown]
# We have exactly 500 documents to work with. Now we can turn our corpus into a matrix of TF-IDF features using `sklearn`'s `TfidfVectorizer()`.

# %%
vectorizer = TfidfVectorizer(decode_error='ignore', max_df=0.9, ngram_range=(2, 2), max_features = 20000)

X = vectorizer.fit_transform(corpus)
X
# Out:
# <500x20000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 762717 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Let's take a look at the vocabulary that was learned by the vectorizer.

# %%
vectorizer.vocabulary_
# Out:
# {'the paper': 16867,
#  'documentstyle 12pt': 5075,
#  'newcommand beq': 10718,
#  'beq begin': 2453,
#  'begin equation': 2403,
#  'equation newcommand': 5727,
#  'newcommand eeq': 10731,
#  'eeq end': 5308,
#  'end equation': 5436,
#  'begin displaymath': 2400,
#  'end displaymath': 5433,
#  'beqa begin': 2464,
#  'begin eqnarray': 2402,
#  'eqnarray newcommand': 5619,
#  'eeqa end': 5322,
#  'end eqnarray': 5435,
#  'partial newcommand': 12394,
#  'renewcommand thefootnote': 13720,
#  'thefootnote fnsymbol': 17385,
#  'fnsymbol footnote': 6394,
#  'footnote renewcommand': 6448,
#  'setcounter footnote': 14470,
#  'renewcommand theequation': 13719,
#  'theequation arabic': 17382,
#  'arabic section': 1567,
#  'section arabic': 14356,
#  'arabic equation': 1565,
#  'equation def': 5683,
#  'def nn': 4581,
#  'nn nonumber': 10776,
#  'nonumber def': 10864,
#  'hbox to': 7701,
#  'value equation': 18859,
#  'setcounter equation': 14469,
#  'equation renewcommand': 5751,
#  'equation begin': 5670,
#  'begin flushright': 2406,
#  '11 end': 71,
#  'end flushright': 5439,
#  'footnote mail': 6445,
#  'center for': 3537,
#  'and particle': 1287,
#  'particle physics': 12446,
#  'physics department': 12677,
#  'department of': 4778,
#  'of physics': 11504,
#  'new york': 10709,
#  'date today': 4474,
#  'maketitle begin': 9950,
#  'begin abstract': 2392,
#  'kinetic term': 9183,
#  'term is': 15745,
#  'is coupled': 8714,
#  'coupled to': 4283,
#  'to bulk': 18146,
#  'bulk scalar': 3035,
#  'vacuum expectation': 18840,
#  'expectation value': 5993,
#  'couplings of': 4300,
#  'kaluza klein': 9122,
#  'klein modes': 9192,
#  'modes to': 10360,
#  'are suppressed': 1706,
#  'giving rise': 7334,
#  'rise to': 14073,
#  'm_ m_': 9888,
#  'this system': 17903,
#  'system can': 15561,
#  'be viewed': 2335,
#  'viewed as': 19067,
#  'regularization of': 13659,
#  'the model': 16754,
#  'model of': 10314,
#  'end abstract': 5426,
#  'newpage section': 10751,
#  'section introduction': 14366,
#  'brane worlds': 2960,
#  'theories with': 17458,
#  'with large': 19698,
#  'extra dimensions': 6056,
#  'number of': 11133,
#  'problems of': 13067,
#  'of high': 11390,
#  'high energy': 7755,
#  'energy physics': 5486,
#  'physics and': 12674,
#  'relations between': 13685,
#  'between them': 2557,
#  'models can': 10331,
#  'as part': 1832,
#  'part of': 12370,
#  'the fundamental': 16464,
#  'higher dimensional': 7759,
#  'dimensional theory': 4960,
#  'described in': 4817,
#  'in terms': 8282,
#  'terms of': 15764,
#  'of strings': 11579,
#  'even if': 5908,
#  'dimensions are': 4966,
#  'are not': 1668,
#  'realized in': 13553,
#  'in nature': 8196,
#  'they are': 17729,
#  'in particle': 8211,
#  'and gravity': 1200,
#  'for some': 6580,
#  'some time': 14884,
#  'time it': 18049,
#  'it was': 9047,
#  'believed that': 2442,
#  'the extra': 16392,
#  'dimensions can': 4968,
#  'only if': 11892,
#  'if they': 7955,
#  'finite volume': 6285,
#  'the problem': 16947,
#  'problem with': 13065,
#  'the infinite': 16577,
#  'infinite volume': 8361,
#  'how to': 7833,
#  'to obtain': 18289,
#  'four dimensional': 6688,
#  'of gravity': 11379,
#  'located at': 9804,
#  'at the': 1944,
#  'the brane': 16061,
#  'brane in': 2938,
#  'work cite': 19782,
#  'was shown': 19152,
#  'shown that': 14530,
#  'the four': 16450,
#  'due to': 5179,
#  'to an': 18118,
#  'term the': 15751,
#  'is described': 8721,
#  'described by': 4816,
#  'the action': 15951,
#  'beq label': 2460,
#  'sqrt cal': 15032,
#  'int dy': 8461,
#  'eeq here': 5310,
#  'here is': 7731,
#  'the coordinate': 16188,
#  'of an': 11208,
#  'an extra': 1008,
#  'extra dimension': 6054,
#  'cal is': 3272,
#  'g_ mn': 7069,
#  'constructed from': 4132,
#  'g_ mu': 7070,
#  'mu nu': 10533,
#  'nu equiv': 11054,
#  'delta mu': 4694,
#  'mu delta': 10487,
#  'nu m_': 11076,
#  'scale of': 14301,
#  'gravity and': 7384,
#  'in order': 8205,
#  'order to': 12031,
#  'obtain the': 11168,
#  'the correct': 16191,
#  'value for': 18860,
#  'newton constant': 10754,
#  'constant on': 4096,
#  'has to': 7539,
#  'be taken': 2317,
#  'sim 10': 14634,
#  'brane is': 2940,
#  'is represented': 8888,
#  'the delta': 16263,
#  'delta function': 4678,
#  'is taken': 8929,
#  'taken to': 15642,
#  'be zero': 2340,
#  'model with': 10325,
#  'with one': 19716,
#  'studied in': 15275,
#  'in cite': 8096,
#  'action ref': 599,
#  'was studied': 19153,
#  'the scale': 17078,
#  'the bulk': 16071,
#  'be as': 2162,
#  'properties of': 13131,
#  'cosmological evolution': 4263,
#  'and string': 1351,
#  'string theory': 15230,
#  'in these': 8289,
#  'system of': 15567,
#  'cal frac': 3261,
#  'frac m_': 6824,
#  'm_ chi': 9881,
#  'is localized': 8815,
#  'find that': 6266,
#  'that at': 15840,
#  'the linearized': 16681,
#  'features of': 6129,
#  'of ref': 11529,
#  'and ref': 1310,
#  'are the': 1709,
#  'the same': 17075,
#  'same in': 14255,
#  'dimensional gravity': 4937,
#  'width of': 19593,
#  'five dimensional': 6312,
#  'conclude that': 3935,
#  'that ref': 15899,
#  'is finite': 8761,
#  'through the': 17943,
#  'will work': 19634,
#  'work with': 19792,
#  'variation of': 18916,
#  'the strength': 17173,
#  'strength of': 15179,
#  'the kinetic': 16638,
#  'term can': 15741,
#  'consequence of': 4046,
#  'coupling to': 4296,
#  'neglect the': 10697,
#  'the gravitational': 16505,
#  'effect of': 5335,
#  'the soliton': 17132,
#  'which is': 19519,
#  'is equivalent': 8747,
#  'equivalent to': 5838,
#  'to zero': 18400,
#  'zero in': 19967,
#  'the next': 16795,
#  'next section': 10756,
#  'the spectrum': 17147,
#  'spectrum of': 14969,
#  'lagrangian in': 9284,
#  'in which': 8308,
#  'which the': 19540,
#  'is function': 8770,
#  'function of': 7003,
#  'results are': 13825,
#  'for scalar': 6572,
#  'scalar and': 14279,
#  'and gauge': 1190,
#  'bulk field': 3032,
#  'field as': 6161,
#  'as well': 1862,
#  'well as': 19373,
#  'as for': 1806,
#  'linearized gravity': 9747,
#  'gravity in': 7387,
#  'in section': 8250,
#  'investigate the': 8623,
#  'modes in': 10356,
#  'system ref': 15569,
#  'and their': 1373,
#  'find the': 6267,
#  'kk modes': 9186,
#  'to matter': 18275,
#  'localized on': 9803,
#  'and from': 1184,
#  'from an': 6941,
#  'an equivalent': 993,
#  'problem of': 13060,
#  'the potential': 16924,
#  'sim sqrt': 14647,
#  'where is': 19445,
#  'contrary to': 4163,
#  'results of': 13832,
#  'of cite': 11252,
#  'where the': 19464,
#  'the different': 16283,
#  'was considered': 19136,
#  'the system': 17219,
#  'the appendix': 15996,
#  'the procedure': 16949,
#  'procedure for': 13071,
#  'finding the': 6268,
#  'of fermionic': 11336,
#  'when the': 19410,
#  'term of': 15746,
#  'of bulk': 11240,
#  'field is': 6178,
#  'in model': 8188,
#  'with non': 19714,
#  'equation in': 5709,
#  'this section': 17878,
#  'of model': 11448,
#  'model in': 10309,
#  'term for': 15743,
#  'is not': 8840,
#  'let us': 9650,
#  'us take': 18716,
#  'field phi': 6185,
#  'x_ mu': 19842,
#  'mu is': 10516,
#  'term to': 15752,
#  'to field': 18215,
#  'partial_ phi': 12425,
#  'phi partial': 12596,
#  'partial phi': 12401,
#  'phi partial_': 12597,
#  'partial_ chi': 12418,
#  'chi chi': 3631,
#  'characterizes the': 3590,
#  'the coupling': 16209,
#  'coupling of': 4294,
#  'of two': 11626,
#  'two fields': 18572,
#  'mu has': 10511,
#  'chi and': 3629,
#  'and can': 1115,
#  'can obtain': 3386,
#  'obtain an': 11162,
#  'value in': 18861,
#  'the form': 16440,
#  'form of': 6636,
#  'then the': 17414,
#  'the lagrangian': 16649,
#  'lagrangian for': 9281,
#  'the field': 16414,
#  'has the': 7538,
#  'the following': 16438,
#  'following form': 6410,
#  'form beq': 6622,
#  'phi eeq': 12568,
#  'phi can': 12554,
#  'gauge field': 7198,
#  'approximation to': 1561,
#  'to find': 18216,
#  'we decompose': 19232,
#  'mu sum_': 10562,
#  'mu where': 10578,
#  'sigma_ sigma_': 14622,
#  'the differential': 16284,
#  'differential equation': 4893,
#  'equation for': 5697,
#  'wave functions': 19165,
#  'is beq': 8675,
#  'partial_ partial_': 12423,
#  'phi_ phi_': 12642,
#  'equations ref': 5807,
#  'for two': 6604,
#  'two different': 18566,
#  'them with': 17397,
#  'and integrating': 1217,
#  'integrating over': 8533,
#  'over the': 12216,
#  'the length': 16668,
#  'length of': 9637,
#  'of extra': 11333,
#  'dimension we': 4920,
#  'we get': 19263,
#  'get the': 7295,
#  'eeq where': 5318,
#  'the normalization': 16812,
#  'normalization constant': 10909,
#  'frac int': 6804,
#  'eeq for': 5309,
#  'for non': 6549,
#  'non negative': 10825,
#  'both the': 2862,
#  'the denominator': 16264,
#  'of this': 11615,
#  'this expression': 17796,
#  'are positive': 1676,
#  'which means': 19524,
#  'means that': 10183,
#  'that there': 15913,
#  'there are': 17547,
#  'are no': 1666,
#  'effective four': 5342,
#  'dimensional action': 4921,
#  'obtained from': 11172,
#  'from ref': 6969,
#  'we can': 19217,
#  'can introduce': 3381,
#  'of field': 11339,
#  'phi to': 12626,
#  'charge density': 3596,
#  'localized at': 9801,
#  'at in': 1916,
#  'in 4d': 8056,
#  'effective theory': 5348,
#  'theory the': 17525,
#  'the coefficient': 16114,
#  'coefficient of': 3818,
#  'of coupling': 11274,
#  'coupling is': 4291,
#  'is determined': 8722,
#  'determined by': 4847,
#  'the matter': 16727,
#  'psi and': 13176,
#  'the wave': 17349,
#  'wave function': 19164,
#  'of wave': 11648,
#  'tilde phi': 18009,
#  'phi equiv': 12570,
#  'equiv int': 5823,
#  'int psi': 8478,
#  'effective action': 5337,
#  'action for': 590,
#  'reads beq': 13535,
#  'frac sum_': 6878,
#  'sum_ left': 15372,
#  'left partial_': 9590,
#  'partial_ mu': 12421,
#  'partial mu': 12393,
#  'sigma_ right': 14621,
#  'right sum_': 14030,
#  'sum_ frac': 15366,
#  'frac tilde': 6888,
#  'phi sqrt': 12615,
#  'sqrt m_': 15051,
#  'zero mode': 19969,
#  'will be': 19600,
#  'choices of': 3675,
#  'integral is': 8517,
#  'while it': 19556,
#  'it will': 9049,
#  'mode in': 10294,
#  'functions that': 7031,
#  'that are': 15838,
#  'pm infty': 12853,
#  'infty this': 8412,
#  'this feature': 17799,
#  'between the': 2556,
#  'the cases': 16085,
#  'cases of': 3468,
#  'spectrum and': 14965,
#  'one has': 11842,
#  'to specify': 18353,
#  'specify the': 14960,
#  'the function': 16461,
#  'function to': 7011,
#  'understand the': 18644,
#  'the connection': 16159,
#  'connection between': 4039,
#  'the shape': 17101,
#  'shape of': 14499,
#  'of and': 11209,
#  'is useful': 8955,
#  'useful to': 18737,
#  'to transform': 18382,
#  'equiv frac': 5820,
#  'potential has': 12967,
#  'left frac': 9546,
#  'frac frac': 6785,
#  'frac left': 6820,
#  'frac right': 6869,
#  'right right': 14021,
#  'right eeq': 13957,
#  'whether this': 19480,
#  'this potential': 17857,
#  'behave as': 2426,
#  'as an': 1777,
#  'an attractive': 980,
#  'depends on': 4788,
#  'the magnitude': 16707,
#  'magnitude of': 9926,
#  'the second': 17085,
#  'second and': 14337,
#  'derivative of': 4797,
#  'the profile': 16952,
#  'now we': 11014,
#  'we consider': 19226,
#  'consider two': 4063,
#  'lead to': 9497,
#  'the localization': 16689,
#  'localization of': 9800,
#  'all of': 757,
#  'example is': 5942,
#  'determines the': 4851,
#  'will give': 19612,
#  'give rise': 7313,
#  'tower of': 18437,
#  'modes with': 10363,
#  'the integer': 16591,
#  'this was': 17913,
#  'was used': 19159,
#  'used as': 18727,
#  'of gauge': 11366,
#  'gauge fields': 7199,
#  'fields in': 6216,
#  'here we': 7737,
#  'because we': 2362,
#  'we will': 19351,
#  'will use': 19633,
#  'use it': 18723,
#  'it as': 8986,
#  'starting point': 15116,
#  'point for': 12886,
#  'the investigation': 16618,
#  'investigation of': 8626,
#  'induced gravity': 8353,
#  'potential ref': 12972,
#  'results from': 13828,
#  'from this': 6978,
#  'potential of': 12970,
#  'of simple': 11555,
#  'harmonic oscillator': 7522,
#  'by constant': 3101,
#  'so that': 14812,
#  'the zero': 17375,
#  'zero point': 19975,
#  'point energy': 12885,
#  'frac sqrt': 6876,
#  'sqrt pi': 15057,
#  'eeq the': 5314,
#  'the interaction': 16601,
#  'interaction of': 8547,
#  'of those': 11616,
#  'with some': 19739,
#  'the value': 17320,
#  'value of': 18863,
#  'function at': 6993,
#  'the position': 16918,
#  'position of': 12934,
#  'the charge': 16097,
#  'charge for': 3597,
#  'for example': 6504,
#  'of charge': 11247,
#  'at is': 1919,
#  'cal sum_': 3303,
#  'for even': 6502,
#  'vanishes for': 18882,
#  'for odd': 6551,
#  'the vanishing': 17322,
#  'vanishing of': 18888,
#  'values of': 18869,
#  'of is': 11414,
#  'is also': 8649,
#  'true for': 18533,
#  'rho the': 13906,
#  'the reason': 17005,
#  'reason is': 13555,
#  'is that': 8930,
#  'functions of': 7029,
#  'of modes': 11450,
#  'while the': 19557,
#  'psi is': 13200,
#  'is even': 8751,
#  'even and': 5905,
#  'this is': 17821,
#  'is presented': 8867,
#  'an example': 998,
#  'example of': 5944,
#  'with finite': 19679,
#  'the kk': 16640,
#  'modes as': 10353,
#  'as one': 1829,
#  'one could': 11827,
#  'expect the': 5991,
#  'potential for': 12966,
#  'for this': 6599,
#  'frac delta': 6760,
#  'consist of': 4073,
#  'of single': 11556,
#  'eeq and': 5307,
#  'potential between': 12963,
#  'between two': 2559,
#  'exchange of': 5959,
#  'establish the': 5846,
#  'the relation': 17019,
#  'relation between': 13670,
#  'us consider': 18704,
#  'consider the': 4061,
#  'the five': 16425,
#  'dimensional model': 4944,
#  'with two': 19757,
#  'action of': 597,
#  'phi the': 12619,
#  'the other': 16862,
#  'chi is': 3636,
#  'is governed': 8777,
#  'governed by': 7363,
#  'brane which': 2957,
#  'of phi': 11501,
#  'phi and': 12542,
#  'is suppressed': 8927,
#  'in powers': 8225,
#  'powers of': 12985,
#  'of fundamental': 11361,
#  'cal left': 3279,
#  'frac chi': 6749,
#  'right partial_': 14009,
#  'function ref': 7006,
#  'since we': 14710,
#  'we take': 19338,
#  'scale is': 14300,
#  'is much': 8825,
#  'bigger than': 2774,
#  'than the': 15820,
#  'number the': 11135,
#  'is shown': 8898,
#  'shown in': 14529,
#  'in fig': 8138,
#  'together with': 18403,
#  'of harmonic': 11386,
#  'vspace 5mm': 19106,
#  'centerline epsfig': 3553,
#  'epsfig file': 5520,
#  'eps width': 5518,
#  'solid line': 14823,
#  'the harmonic': 16521,
#  'dashed line': 4471,
#  'line is': 9734,
#  'is in': 8790,
#  'in units': 8300,
#  'units of': 18670,
#  'potential is': 12969,
#  'for small': 6577,
#  'small values': 14779,
#  'coincides with': 3830,
#  'sim the': 14649,
#  'the square': 17159,
#  'this behavior': 17760,
#  'of states': 11576,
#  'bound states': 2869,
#  'states of': 15154,
#  'and will': 1427,
#  'we are': 19206,
#  'are interested': 1646,
#  'interested in': 8563,
#  'the case': 16084,
#  'case of': 3450,
#  'gravity we': 7396,
#  'we want': 19349,
#  'want to': 19127,
#  'the decay': 16247,
#  'of zero': 11662,
#  'that will': 15927,
#  'sim and': 14636,
#  'and are': 1088,
#  'low energy': 9857,
#  'approximation for': 1556,
#  'mode is': 10295,
#  'sim exp': 14639,
#  'exp left': 5973,
#  'left int_': 9559,
#  'y_1 y_2': 19915,
#  'points and': 12904,
#  'and is': 1218,
#  'the well': 17356,
#  'for large': 6535,
#  'large values': 9447,
#  'condition for': 3958,
#  'is well': 8960,
#  'everywhere except': 5917,
#  'except at': 5954,
#  'points the': 12910,
#  'the integral': 16595,
#  'integral in': 8516,
#  'in ref': 8242,
#  'be evaluated': 2208,
#  'the large': 16656,
#  'range of': 13486,
#  'of values': 11637,
#  'is independent': 8794,
#  'independent of': 8332,
#  'behaves as': 2427,
#  'therefore in': 17566,
#  'sim frac': 14640,
#  'the continuous': 16177,
#  'be found': 2222,
#  'found by': 6680,
#  'by solving': 3162,
#  'solving the': 14868,
#  'equation we': 5785,
#  'we find': 19255,
#  'the couplings': 16210,
#  'explore the': 6020,
#  'the question': 16985,
#  'question of': 13428,
#  'gravity to': 7395,
#  'to brane': 18142,
#  'different types': 4890,
#  'types of': 18613,
#  'of matter': 11444,
#  'have different': 7636,
#  'would be': 19806,
#  'be non': 2262,
#  'can in': 3380,
#  'in fact': 8136,
#  'property of': 13133,
#  'of models': 11449,
#  'models with': 10350,
#  'dimensions it': 4973,
#  'the possibility': 16922,
#  'the cosmological': 16202,
#  'cosmological constant': 4262,
#  'constant problem': 4097,
#  'the resulting': 17048,
#  'theory this': 17530,
#  'was pointed': 19150,
#  'pointed out': 12902,
#  'out to': 12126,
#  'for theories': 6595,
#  'brane cite': 2929,
#  'we adopt': 19199,
#  'adopt the': 638,
#  'violation of': 19069,
#  'suppressed by': 15489,
#  'scale the': 14302,
#  'scalar field': 14282,
#  'field that': 6191,
#  'mass scale': 10006,
#  'mass of': 10003,
#  'of standard': 11574,
#  'standard model': 15098,
#  'fields is': 6217,
#  'the cutoff': 16227,
#  'come from': 3844,
#  'mode of': 10296,
#  'of another': 11212,
#  'the mass': 16717,
#  'is due': 8735,
#  'to some': 18352,
#  'higher order': 7762,
#  'zero modes': 19970,
#  'can have': 3378,
#  'are different': 1613,
#  'because of': 2357,
#  'of their': 11606,
#  'large mass': 9441,
#  'now let': 11006,
#  'return to': 13838,
#  'of potential': 11511,
#  'for ref': 6567,
#  'be solved': 2308,
#  'for simplicity': 6575,
#  'simplicity we': 14675,
#  'the continuum': 16178,
#  'modes the': 10359,
#  'the qualitative': 16976,
#  'behavior of': 2432,
#  'functions is': 7028,
#  'is as': 8661,
#  'as follows': 1804,
#  'outside the': 12128,
#  'functions are': 7021,
#  'plane waves': 12830,
#  'inside the': 8429,
#  'with mass': 19703,
#  'one can': 11821,
#  'can take': 3400,
#  'tilde psi': 18014,
#  'for each': 6498,
#  'dependence of': 4783,
#  'the graph': 16501,
#  'are at': 1585,
#  'positions of': 12936,
#  'plot of': 12838,
#  'the solid': 17131,
#  'to show': 18345,
#  'show the': 14521,
#  'there is': 17554,
#  'zero this': 19979,
#  'zero mass': 19968,
#  'that is': 15876,
#  'is responsible': 8891,
#  'responsible for': 13792,
#  'the 4d': 15937,
#  'coupling and': 4285,
#  'see the': 14415,
#  'the log': 16692,
#  'the half': 16517,
#  'of can': 11244,
#  'numerical analysis': 11140,
#  '10 10': 37,
#  '10 we': 59,
#  'delta sim': 4719,
#  'besides the': 2470,
#  'is no': 8835,
#  'no other': 10788,
#  'to higher': 18240,
#  'that have': 15873,
#  'in particular': 8212,
#  'the results': 17049,
#  'is given': 8775,
#  'given by': 7321,
#  'by beq': 3090,
#  'int_ infty': 8492,
#  'infty frac': 8397,
#  'm_ frac': 9883,
#  'approx frac': 1554,
#  'frac quad': 6862,
#  'here the': 7735,
#  'is supported': 8925,
#  'at large': 1922,
#  'large distances': 9434,
#  'only the': 11900,
#  'the lightest': 16674,
#  'contribute to': 4167,
#  'the exchange': 16375,
#  'phi approx': 12543,
#  'and one': 1273,
#  'eeq this': 5315,
#  'potential as': 12960,
#  'as in': 1813,
#  'of massive': 11436,
#  'smaller than': 14781,
#  'the force': 16439,
#  'to reproduce': 18329,
#  'reproduce the': 13759,
#  'to take': 18365,
#  'take the': 15636,
#  'be of': 2265,
#  'the order': 16851,
#  'order of': 12022,
#  'planck scale': 12822,
#  'massive spin': 10022,
#  'spin two': 14993,
#  'structure of': 15264,
#  'the propagator': 16959,
#  'shown cite': 14527,
#  'that non': 15887,
#  'non linear': 10821,
#  'this problem': 17858,
#  'problem in': 13058,
#  'model cite': 10305,
#  'conjecture that': 4028,
#  'that similar': 15904,
#  'occurs in': 11184,
#  'model at': 10301,
#  'at hand': 1913,
#  'of that': 11605,
#  'as the': 1851,
#  'two and': 18555,
#  'and three': 1386,
#  'in progress': 8232,
#  'vspace 1cm': 19098,
#  'bf acknowledgments': 2641,
#  'would like': 19812,
#  'like to': 9689,
#  'to thank': 18368,
#  'for useful': 6607,
#  'grateful to': 7369,
#  'for discussion': 6495,
#  'to make': 18270,
#  'make this': 9940,
#  'newpage begin': 10750,
#  'appendix section': 1523,
#  'method for': 10204,
#  'for fermions': 6505,
#  'equation here': 5706,
#  'spectrum for': 14966,
#  'field with': 6202,
#  'term that': 15750,
#  'dimension the': 4919,
#  'action we': 605,
#  'bar psi': 2098,
#  'psi gamma_': 13196,
#  'partial psi': 12403,
#  'algebra in': 714,
#  'in 5d': 8057,
#  'gamma gamma': 7121,
#  'be satisfied': 2302,
#  'choice of': 3673,
#  'of 4d': 11195,
#  'gamma matrices': 7134,
#  'gamma mu': 7135,
#  'mu and': 10462,
#  'and gamma': 1188,
#  'equiv gamma': 5821,
#  'gamma the': 7157,
#  'the equation': 16357,
#  'equation of': 5732,
#  'of motion': 11455,
#  'motion is': 10437,
#  'is solved': 8909,
#  'the ansatz': 15989,
#  'beqa label': 2466,
#  'psi sum_': 13230,
#  'right nn': 13997,
#  'gamma_ mu': 7175,
#  'mu mu': 10528,
#  'xi_ xi_': 19907,
#  'eeqa where': 5325,
#  'dirac spinor': 4997,
#  'frac gamma': 6789,
#  'quad frac': 13343,
#  'same as': 14251,
#  'dimensional effective': 4930,
#  'be different': 2196,
#  'since one': 14702,
#  'into ref': 8588,
#  'over we': 12223,
#  'we obtain': 19298,
#  'left bar': 9523,
#  'f_ mn': 6080,
#  'frac bar': 6734,
#  'where f_': 19438,
#  'mn is': 10285,
#  'is an': 8651,
#  'an infinite': 1013,
#  'infinite dimensional': 8358,
#  'dimensional matrix': 4941,
#  'fourier transform': 6695,
#  'transform of': 18474,
#  'as their': 1852,
#  'is now': 8842,
#  'reduced to': 13578,
#  'of infinite': 11402,
#  'mn and': 10282,
#  'be done': 2198,
#  'done in': 5089,
#  'and we': 1420,
#  'can write': 3407,
#  'psi dagger': 13186,
#  'psi psi': 13220,
#  'dagger psi': 4461,
#  'lambda_ lambda_': 9389,
#  'equiv sum_': 5832,
#  'psi_ bar': 13241,
#  'where we': 19472,
#  'matrices are': 10097,
#  'are chosen': 1593,
#  'chosen to': 3683,
#  'to diagonalize': 18184,
#  'diagonalize the': 4860,
#  'and mass': 1241,
#  'mass term': 10010,
#  'the simplest': 17113,
#  'which case': 19494,
#  'delta and': 4654,
#  'we recover': 19310,
#  'simple example': 14668,
#  'is delta': 8717,
#  'delta in': 4686,
#  'in that': 8283,
#  'that case': 15851,
#  'eigenvalues of': 5359,
#  'are zero': 1728,
#  'one that': 11865,
#  'is infinite': 8796,
#  'infinite number': 8359,
#  'of positive': 11509,
#  'from to': 6980,
#  'only one': 11898,
#  'will have': 19613,
#  'this case': 17765,
#  'the diagonal': 16278,
#  'the lower': 16702,
#  'left to': 9617,
#  'all other': 759,
#  'it would': 9051,
#  'be interesting': 2242,
#  'interesting to': 8564,
#  'and compare': 1123,
#  'it to': 9044,
#  'results obtained': 13831,
#  'obtained by': 11170,
#  'term on': 15747,
#  'gravity on': 7390,
#  'on brane': 11751,
#  'minkowski space': 10275,
#  'space phys': 14921,
#  'phys lett': 12655,
#  'lett bf': 9651,
#  '2000 hep': 203,
#  'hep th': 7724,
#  'phys rev': 12661,
#  'rev lett': 13840,
#  'bf 84': 2633,
#  '2000 arxiv': 201,
#  'arxiv hep': 1773,
#  'the power': 16926,
#  'power of': 12982,
#  'of brane': 11238,
#  'gravity phys': 7391,
#  'rev bf': 13839,
#  'bf 64': 2625,
#  'hep ph': 7723,
#  'citation hep': 3702,
#  'scales of': 14306,
#  'bf 65': 2626,
#  '2002 arxiv': 209,
#  'effects on': 5352,
#  'extra dimensional': 6055,
#  'nucl phys': 11125,
#  'phys bf': 12652,
#  '2001 arxiv': 205,
#  'in minkowski': 8187,
#  'standard cosmology': 15095,
#  'cosmology in': 4266,
#  'brane model': 2942,
#  'bf 32': 2594,
#  'dvali and': 5182,
#  'from gravity': 6956,
#  'dimensions phys': 4977,
#  'arxiv astro': 1771,
#  'astro ph': 1891,
#  'citation astro': 3699,
#  'brane cosmology': 2932,
#  'term in': 15744,
#  'in ds': 8119,
#  'jhep bf': 9088,
#  'casimir energy': 3474,
#  'energy and': 5467,
#  'in five': 8143,
#  'six dimensional': 14750,
#  'bf 0106': 2564,
#  ...}

# %%
vectorizer.stop_words_
# Out:
# {'g_2 subset',
#  'eqletter where',
#  'again within',
#  '229 1991',
#  'needs accelerations',
#  'j_k the',
#  '30 32',
#  'peebles phys',
#  'phys leipzig',
#  'those neutral',
#  'theta_k theta_',
#  '36 based',
#  'parameters la_b',
#  'these papers',
#  'mathbf in',
#  'rigorously by',
#  'physical terminology',
#  'term being',
#  'else protect',
#  'version section',
#  'matrix a_1',
#  'requires specification',
#  'people it',
#  'so obvious',
#  'goldwirth 1991rj',
#  'curved backgrounds',
#  'calling these',
#  'cartan atiyah',
#  'with solitonic',
#  'lev in',
#  'hawking predict',
#  'bakasi we',
#  'exs t_',
#  'providing efficient',
#  'vk dagger',
#  'following hyperbolic',
#  'maxim textsc',
#  'phys b556',
#  'integrals begin',
#  'not homogeneous',
#  'cite brustein01',
#  'behavior using',
#  'flux 64',
#  'cc ast',
#  'regard to',
#  'superfields n_',
#  'matter clearpage',
#  'eqn svarl',
#  'all sure',
#  'by pp',
#  'ox1 3lb',
#  'th 0211017',
#  'regularized quantum',
#  'a_f pi',
#  'connected element',
#  'with asking',
#  'eqnarray luckily',
#  'karmanov93 we',
#  'indicates superfield',
#  'k_n acts',
#  'nu l_2',
#  'aantz enr',
#  'ref usf_fml',
#  'has eigenvalue',
#  'and planarcut',
#  'lambda_2 begin',
#  'triplet is',
#  'deformed superalgebra',
#  'def fiic',
#  'quantities inaccessible',
#  'trim size',
#  'aw9uiglzig5vdywgxgjlifx0agv0yqo9tv97mtf9xjncaw50x3tyfsbdxzms ifxlzsb3agvyzsakq18zjcbpcybhz2fpbib0agugdghyzwugzm9ybsbvzgox',
#  'which lack',
#  'parameters lambda',
#  'phi given',
#  'label asm5',
#  'rr pa_r',
#  'being required',
#  'choice should',
#  'bgs in',
#  'introductive chapters',
#  'ip_1x ip_2y',
#  'tilde discussed',
#  'times hermitian',
#  'discussions newpage',
#  'into network',
#  'wave asymptotically',
#  '83 with',
#  'where pmatrix',
#  'black includefigures',
#  'lyth it',
#  'menlo park',
#  'equiv h_2',
#  'books item',
#  'theories dealing',
#  'even genuinely',
#  'psfrag kappa',
#  'mail to',
#  'commut cc',
#  'period coincides',
#  'holonomy em',
#  'computation shows',
#  'long ranged',
#  'sheet bosons',
#  'z_ p_r',
#  'seki our',
#  'vartheta im',
#  'mathpalette fun',
#  'acting su',
#  'fss1 the',
#  'stemlengthx by',
#  'tour 16',
#  'ito cite',
#  'cite castelino',
#  'theory suppose',
#  'called transformation',
#  'backgrounds as',
#  '9712257 bbt',
#  'rule corresponds',
#  'for tbl',
#  'when condensed',
#  'n88 the',
#  'had mostly',
#  'us cover',
#  'classical einstein',
#  'fe respectively',
#  'on ra',
#  'corri lambda_r',
#  '9712062 the',
#  '101 13',
#  'q_i tilde',
#  'compactifications can',
#  'mandelstam see',
#  'another transformation',
#  'laser fields',
#  'of ingredient',
#  'fortunately only',
#  'small policastro',
#  'abssy scriptfont2',
#  'noindent square',
#  'predicted from',
#  'frac rh',
#  'check now',
#  'rangle obeying',
#  'fermion minimally',
#  'this document',
#  'star ds',
#  'p_n bra',
#  '1984a bordemann',
#  'then involves',
#  'a_u using',
#  'junction it',
#  'sigma directions',
#  'namplimog lim_',
#  'za mo',
#  'in 1n',
#  'atomic spectroscopy',
#  'for n_l',
#  'newblock cambridge',
#  'psi sigma_2',
#  'alpha eqs',
#  'eqn green',
#  'pi_i over',
#  'sixopen msbm6',
#  'xi_r dag',
#  'b350 441',
#  'holomorphic maps',
#  '60 140',
#  'as negative',
#  'define critical',
#  'mehen rangamani',
#  'asym1 is',
#  'see howe',
#  '15 ff',
#  'viallet hamiltonian',
#  'critical clusters',
#  'star 2n',
#  '64 40',
#  'could see',
#  'vector_poles to',
#  'naively thought',
#  'firstly discussed',
#  'simple contour',
#  'b_5 b_6',
#  'are survived',
#  'still take',
#  'textrm diag',
#  'lightcone coordinate',
#  'varphi_c simeq',
#  'cite gao',
#  'the complexes',
#  'moore metr',
#  'relating two',
#  'physics experimentally',
#  'peresekajushihsja wetwej',
#  'further from',
#  'deft can',
#  'after is',
#  'covariant definition',
#  'th 9708168',
#  'fermion polarizations',
#  'callan myers',
#  'two issues',
#  'which chi_',
#  'globality we',
#  'gets outgoing',
#  'multiplying odd',
#  'derk mbw_l',
#  'dodelson for',
#  'dots it',
#  'kaw bor1',
#  'fractions can',
#  'krylov em',
#  'interesting ones',
#  'np textbf',
#  'in sfit',
#  'noncommutative in',
#  'dots 4n_',
#  'line fields',
#  'and correctness',
#  'space classical',
#  'cite dobashi',
#  'non sum_',
#  'first move',
#  'bibitem govindarajan',
#  'bibitem pi98',
#  '339 258',
#  'construction done',
#  'super emph',
#  'appear from',
#  'electrical currents',
#  'thermodynamics let',
#  'eigenstates which',
#  'building models',
#  '0209115 bibitem',
#  'subuniverse where',
#  'f_r eqq',
#  'hourmin titlepage',
#  'we chosen',
#  'cp whose',
#  'exp star',
#  'puzzling begin',
#  'coupled and',
#  'normalization theorems',
#  'times because',
#  'dual purpose',
#  'sigma_i wedge',
#  'furthermore hat',
#  'frac 648',
#  'whose interpretation',
#  'follows textbf',
#  'phic2 varphi_',
#  'ga see',
#  'masses chiral',
#  'alpha ia',
#  'observations our',
#  'through lambda_5',
#  'subset times',
#  'analogous spontaneous',
#  'is bicoloured',
#  'bf under',
#  'xi theta',
#  'dbend lower3',
#  'linewidth lev0000_00',
#  'sum n_l',
#  'generally expect',
#  '1988 and',
#  'another chain',
#  'omega_i delta_',
#  'exp h_1',
#  'unitary theory',
#  'in triangular',
#  '228 1983',
#  'ruegg zakrzewski',
#  'cavity casimir',
#  'ck b_',
#  'mt for',
#  '0203019 citation',
#  'wise inverse',
#  '0106022 arxiv',
#  'ldots sum_',
#  'ym while',
#  'reason so',
#  'anti brs',
#  'mc rho_1',
#  'h_6 bz',
#  'frame delta',
#  'partial_z phi',
#  'minkowskian equations',
#  'rm un',
#  'emph one',
#  '_i circ',
#  'boomerang dasi',
#  'ordering ops',
#  'dbiac beqa',
#  'justify to',
#  'psfrag wurzel',
#  'parti nikitin',
#  'ij provided',
#  'hyperbolic function',
#  'dualtr involving',
#  'bf replaced',
#  'ts and',
#  'introdced collective',
#  'using coordinates',
#  'selfgammaonediff tilde',
#  'centerline closed',
#  'to kaluza',
#  'chiminall shows',
#  'cite lump',
#  'l_a with',
#  'lacks the',
#  'taken advantage',
#  'r_i mu',
#  '38 right',
#  'leptons of',
#  'einstein dirac',
#  'decides the',
#  'infty ee',
#  'clearly 28',
#  '83g 2n',
#  '52 51',
#  'additional step',
#  'analysis leading',
#  'category as',
#  'n_i vanish',
#  'newcommand vpbar',
#  'parameters m_i',
#  'op mathop',
#  'three differential',
#  'newcommand nablab',
#  'psg in',
#  'r_0 focusing',
#  'goes on',
#  'map rightarrow',
#  'com com',
#  'this forbids',
#  'now shown',
#  '0209164 citation',
#  'psi ov',
#  'obtain at',
#  'psboundary1 and',
#  'removing braiding',
#  'explore three',
#  'graphs on',
#  'in v_',
#  '2k independently',
#  'f2 this',
#  'and fulfils',
#  '2m_0 eta',
#  'fun cc_',
#  'label kleba',
#  'textbf b134',
#  'have remarkably',
#  'for technicality',
#  'ijkl ijkl',
#  'rjj suppose',
#  'particular numerical',
#  'spectator role',
#  '44s 152s',
#  'example corresponds',
#  'order estimate',
#  'eq hh',
#  'currents exists',
#  'symmetry prerequisite',
#  'hfill pupt',
#  'dualeom1 and',
#  'fiz 56',
#  'module elements',
#  'couplings beq',
#  'initially met',
#  'trivial flux',
#  'elsevier 1989',
#  'spinors pick',
#  'because x_',
#  'variable x_',
#  'm_0 where',
#  'again diluted',
#  'truncation to',
#  'more concrete',
#  'root vectors',
#  'frac cl',
#  'ring cup',
#  'results remain',
#  'approach gives',
#  '2001dm kiem',
#  'april 10',
#  'theta_0 end',
#  'of decreasing',
#  'ref bps14energy',
#  'it closely',
#  'corradowx the',
#  'sum bigl',
#  'right 26b',
#  'mail rm',
#  'all arbitrary',
#  'i_s label',
#  'variation has',
#  'b21 346',
#  'denoted collectively',
#  'hand branes',
#  'worldsheet duality',
#  'wiseman email',
#  'exactly allows',
#  '0004072 bibitem',
#  '5ex hbox',
#  'inverse varepsilon',
#  'metrics complete',
#  'describing higher',
#  'bpz they',
#  'from psg',
#  'k_i lk_i',
#  'g_n m_1',
#  '31 32',
#  'rho frac38',
#  'witten whitham',
#  'betauno left',
#  'at commas',
#  'com ga',
#  'metastable rather',
#  'potwrit over',
#  'expects topological',
#  'fw friedmann',
#  'heap nagle',
#  'its state',
#  'gluing all',
#  'ydri ydri',
#  'jk quad',
#  'that lie',
#  'operators b_',
#  'diagrams thus',
#  'soliton without',
#  'hepth 9802004',
#  'harr izdos',
#  'deformations general',
#  'fluxes or',
#  'is ads_3',
#  'neto for',
#  'put w_2',
#  'triangle kogan',
#  'dilatino without',
#  'first introduce',
#  'between formula',
#  'f_j k_ik_i',
#  'framework goes',
#  '1999 for',
#  'omega_ k_i',
#  'ik bf',
#  'the diffeomorphisms',
#  'is afforded',
#  'ep lan',
#  'equation consistent',
#  'and cowardly',
#  'ifnum minute',
#  'have remained',
#  'smedback on',
#  '0105175 matsuo',
#  'thmm trivlist',
#  'decays from',
#  '2n point',
#  'satisfies varepsilon_',
#  'two fixed',
#  'textit cosmology',
#  'ol3 lauscher',
#  'mz2 aio',
#  'counterterms needed',
#  '25 scs',
#  't_1 qquad',
#  'generator section',
#  '1999 423',
#  'alpha de',
#  'whole bubble',
#  'generally massive',
#  'importantly for',
#  'subset a_0',
#  'representation our',
#  'pi_0 varepsilon_0',
#  'fig let',
#  'liouville plus',
#  'cite dam2',
#  'gaussian wave',
#  'here yields',
#  'rangle l_0',
#  'bibitem matone',
#  'eqn ftermgauge',
#  'arstrut preamble',
#  'convenience then',
#  'free before',
#  'e_ quad',
#  'kern 55em',
#  'pm g_0',
#  'full deformed',
#  'two vevs',
#  'redefinitions cite',
#  'notag epsilon',
#  'pi arg',
#  'actually relative',
#  'complication arises',
#  'dewolfe 2001pq',
#  'product beqa',
#  '_2 discussed',
#  'beta_1 sum_ie_i',
#  'certain types',
#  'values widehat',
#  'preserved spacetime',
#  'fulfilled operator',
#  '237 href',
#  'lambda_0 determined',
#  'cite lsint',
#  '31 33',
#  'classical amplitude',
#  '4eh ds_4',
#  'superconductivity vortices',
#  '535 class',
#  'a_1 2t',
#  'eq_norm becomes',
#  'amount remarkably',
#  'parameterization label',
#  'eta_2 the',
#  'spacetime bea',
#  'correspondence corrections',
#  'harvey kraus',
#  '0012210 bibitem',
#  'master2 in',
#  'dual equation',
#  'generation supersymmetric',
#  'this guarantees',
#  'eeq x_',
#  'triviality is',
#  'cast precisely',
#  'ganor hep',
#  'put 30',
#  '400 cite',
#  'sum_ie_i frac',
#  'nserc of',
#  'susytr begin',
#  'n_0 but',
#  'gs gross',
#  'alpha controls',
#  'label torus',
#  'emph classical',
#  'us remark',
#  '0204 049',
#  'ii multicolumn',
#  'have ell',
#  'precisely lead',
#  'typical range',
#  'conjugates as',
#  '2e sinh',
#  'therefore second',
#  'secondly note',
#  'wedge gamma',
#  'gn considering',
#  'value which',
#  'parameters newsection',
#  'way plus',
#  'right g_5',
#  '19 were',
#  't_a act',
#  'ijk bar',
#  'def bod',
#  '012 end',
#  'with fermi',
#  'nobreak immediate',
#  'identities leave',
#  'label fig5',
#  'right g_2',
#  '0301078 bibitem',
#  'ring whose',
#  'cite ans',
#  'in complementary',
#  'homogeneous frame',
#  'v_l end',
#  'em operator',
#  '1998 bibinfo',
#  '0207117 citation',
#  'affil email',
#  '_0 eta',
#  'can minimize',
#  'label cycle',
#  'enthalpy hence',
#  'gks gives',
#  'fig sign',
#  'today rho_r',
#  'feb and',
#  'f5fierz change',
#  'ta right',
#  'steer and',
#  'vol mcgraw',
#  'operatorname ker',
#  'theta_ ab',
#  'equation rescaling',
#  'leads priori',
#  'label etaalpha',
#  'binding force',
#  'widehat partial',
#  'cosine cosh',
#  '2n_a x_c',
#  'cite constable1',
#  'mail semenoff',
#  'others distinguishes',
#  'x_1 this',
#  'corrections will',
#  'drastically improved',
#  'patterns observed',
#  'small anyway',
#  'that gets',
#  'section large',
#  'big symbols',
#  'a_l mhat',
#  'several first',
#  'various orbifold',
#  'in omega_2',
#  'represents nonultralocal',
#  'inserted at',
#  'of reads',
#  'lopez cite',
#  'loyal subjects',
#  '7cm t_',
#  'bigg int_q',
#  'antighost it',
#  '10th tohwa',
#  'further analyzed',
#  'frac sigma_3',
#  'mp_ lm',
#  'modified special',
#  'rhs similar',
#  'perturbative constructive',
#  'no propto',
#  'states extending',
#  'and recently',
#  'mid xi',
#  'qquad nam',
#  'maartens germani',
#  'called hedgehog',
#  'multi vortex',
#  'of confined',
#  'r_t phi',
#  'volumes but',
#  'theories among',
#  'sol phi',
#  'rest more',
#  'resultant predictions',
#  'eigen it',
#  't_1 cr',
#  'epss epsilon_',
#  '017 1998',
#  'as cuts',
#  'additional set',
#  'action hep',
#  'live it',
#  '1985yj alvarez',
#  'coordinate patches',
#  'superpotential s_',
#  '10 through',
#  'varying potential',
#  'over 320',
#  'used term',
#  'cg of',
#  'spho m_',
#  'using as',
#  'la f_p',
#  'n84 lee',
#  'yukawa term',
#  'bulk x_b',
#  'whole volume',
#  '_j eta',
#  'ww_n frac',
#  'witten 1996im',
#  'of writing',
#  'phi_n correspond',
#  'fields admitting',
#  'have h_p',
#  'reflecting nonexistence',
#  'pi mapsto',
#  'sec3 section',
#  'commend ed',
#  '890 2851',
#  'chi_2 begin',
#  'derived on',
#  'hh ee',
#  'problem nor',
#  'put 2251',
#  'alpha_3 end',
#  'amssymb tightenlines',
#  'winding vector',
#  'for coincident',
#  'classes enforcing',
#  'bibitem mitra',
#  '4pt stackrel',
#  '_5 partial',
#  'to conacyt',
#  'geq label',
#  'kovchegov and',
#  'cut represents',
#  'variables dot',
#  'spacetime vanishes',
#  'propagator due',
#  'easily absorbed',
#  'fft14 fft12',
#  'phi z_2',
#  'duff textit',
#  '12 partial_n',
#  'relative magnitude',
#  'bf or',
#  'difflambda end',
#  'substituting 35',
#  'sur have',
#  'lusz16 these',
#  'part so',
#  'claim on',
#  'bbar 66',
#  'died or',
#  'encourage us',
#  'also respects',
#  'bx over',
#  'each field',
#  'geometrical theory',
#  'should actually',
#  'turn recall',
#  'susy deals',
#  'promising methods',
#  'dual d5',
#  'coboundaries in',
#  'ap2 even',
#  'ford2 for',
#  'in reals',
#  'mu_t the',
#  '47 hspace',
#  's_2 of',
#  'physical excitations',
#  '0205251 kanti',
#  'for horizons',
#  'determine metric',
#  'in intense',
#  'phi0 ref',
#  'type ggtgt',
#  '631 bi',
#  'inflation invited',
#  'cite plane',
#  'couple but',
#  'processes between',
#  'for arbitary',
#  'it autoduality',
#  'spirit to',
#  'left gtti',
#  'collide they',
#  'forbids them',
#  'lorentzian picture',
#  'and nishino',
#  'on class',
#  'namely note',
#  'gor gorsky',
#  'hold after',
#  'nieuwenhuizen no',
#  'condensation except',
#  'functions varphi',
#  'fac the',
#  'to d7',
#  'here nabla',
#  'directions vskip',
#  'background having',
#  '770 820',
#  'sg dd',
#  'amazing what',
#  'possesses many',
#  'by however',
#  'ccl eta',
#  'forth and',
#  'expanding of',
#  'editions of',
#  'with polytropic',
#  'row because',
#  'to correspond',
#  'particlelengthx unitboxwidth',
#  't_2 mu',
#  'torus end',
#  'ref bfield',
#  'pottsabc parbox',
#  'fm hline',
#  'economical way',
#  'al prod_k',
#  'the loss',
#  'cohomology bianchi',
#  'ga_3 nonumber',
#  'r_0 eea',
#  'mcmahon and',
#  'bar d2',
#  'z_n using',
#  'remains useful',
#  'vacha1 vacha2',
#  '0210291 cite',
#  'classical analogs',
#  'for wilson',
#  'seven myers',
#  'style of',
#  'rpf with',
#  'glueball spectrum',
#  'defect line',
#  'constant bea',
#  'leq q_a',
#  'for continuous',
#  'occurs or',
#  'right j_r',
#  'consider iib',
#  'dependent from',
#  '58 125003',
#  'tkin end',
#  'subsection boundary',
#  'h_2 times',
#  'allow such',
#  'area labels',
#  'textit connected',
#  'beta psi',
#  'eqnarray zeta',
#  'basis function',
#  'complex component',
#  'kul02a and',
#  '1969 666',
#  'ref feta',
#  'cite mtb',
#  'for j_',
#  'th 9809084',
#  'sin2f sin',
#  'schiff already',
#  'directions determined',
#  'degree and',
#  'space label',
#  'bianca physics',
#  'that m_3',
#  'tajima and',
#  'having cal',
#  'various fractions',
#  'eqref isingaux',
#  'ldots subsection',
#  'qad l_',
#  'md_m phi',
#  '8in epsfbox',
#  'cite pandotse',
#  'also ref',
#  'the schwartzschild',
#  'string no',
#  'but associativity',
#  'alpha_b n_3',
#  'parities ghost',
#  'astute ways',
#  'closed manifolds',
#  'bclambda and',
#  'alpha belong',
#  'mukohyama shiromizu',
#  'exponent label',
#  'event in',
#  'commutators one',
#  'monopole so',
#  'equality shows',
#  'through by',
#  '557 ref',
#  'is control',
#  'algebraically this',
#  'influ is',
#  'positron system',
#  'volume bibitem',
#  'forever in',
#  'nuc and',
#  'sim ls',
#  'inverse surface',
#  'is uplifted',
#  'give insights',
#  'pm no',
#  'hamiltonian free',
#  'the holonomic',
#  'velocity fluctuations',
#  'massive consider',
#  '8d should',
#  'subsubsection relation',
#  'except one',
#  'that involve',
#  'moderately high',
#  'length element',
#  'damage that',
#  'eqno 31b',
#  'bibitem jade',
#  'brane symmetry',
#  'kofman gravitational',
#  '2002jq more',
#  'would reduce',
#  'solutions besides',
#  'frac12 def',
#  'd_4 left',
#  'conjugate particular',
#  'underlying lattice',
#  '2000 38',
#  'rput pottsnew',
#  'a_ l_2',
#  '9407055 citation',
#  'hlavkun96 the',
#  'generic mu',
#  'rangle to',
#  'further restricts',
#  'asim in',
#  'cite stau',
#  'eq covfietwo',
#  'ref action10',
#  'quasi hopf',
#  'broken currents',
#  'product vert',
#  'does that',
#  '13 theta',
#  'b_2 ab',
#  '2p mu',
#  'mu components',
#  'obtained described',
#  'ordering abc',
#  'spherical shape',
#  'conservation eq',
#  'mode eps',
#  'three spacetime',
#  'nontrivial leftover',
#  '_q from',
#  'conventional harmonic',
#  'particular bu',
#  'point separating',
#  'ahh vspace',
#  'constant no',
#  'life and',
#  'nonabelian brane',
#  'interesting issues',
#  'antisymmetrized in',
#  'recognized for',
#  'ast2 takes',
#  'extend in',
#  'again result',
#  'on brs',
#  'miss classification',
#  'equiv f_p',
#  'with qquad',
#  'doubly charged',
#  'c_ viii',
#  'eqn schw',
#  'label xp2',
#  'coordinates z_',
#  'superfields it',
#  'eqns 5b',
#  'time beyond',
#  'siegel it',
#  '95 10',
#  '2pt brane',
#  'times 14a',
#  'th 0112258',
#  'newcommand adjoint',
#  'titlepage body',
#  'equations universally',
#  '56 psi',
#  'ref eqa2',
#  'gar which',
#  'stationary axisymmetric',
#  'left invariance',
#  'are deo',
#  'cih cal',
#  'remained with',
#  '2mnr triangle_',
#  'defining connections',
#  'have rightarrow',
#  '12 if',
#  'epsfxsize truecm',
#  'ddasympldef eeq',
#  'omega still',
#  'isometry suggests',
#  'v_i it',
#  'distances may',
#  'beta lambda_1',
#  'subsec tadpoles',
#  'suffixes and',
#  'twist finally',
#  'each value',
#  'req while',
#  'shiang feng',
#  'vert_0 3h_b',
#  'anomalies on',
#  'in kst',
#  'attempt is',
#  'insertion rangle',
#  'be morita',
#  'auxa_i bdd_',
#  'minors of',
#  'int_m rho',
#  'hj ca',
#  'vac x_1',
#  'arabic enumi',
#  'essentially because',
#  'equiv bs',
#  'fzs sin',
#  'planck relation',
#  'fa it',
#  'eqn parameters',
#  'antipodal point',
#  'alto alimohammadi',
#  'c_ rr',
#  'the nodes',
#  '1988 221',
#  ...}

# %% [markdown]
# We can see from the stopwords learned by the vectorizer that it can safely exclude a lot of the LaTeX terms. A few physics terms were caught in the filter, but the benefit should outweigh this cost. (After all, they must not be very distinctive phrases if they're occurring in 90% of papers.)
#
# The top of the vocabulary shows some additional LaTeX phrases that occur frequently and are not informative to us. We'll go ahead and remove those low-hanging fruit using by retraining the vectorizer and passing these stop-phrases as a list.

# %%
additional_stopwords = list(vectorizer.vocabulary_)[0:50]

# %%
vectorizer = TfidfVectorizer(decode_error='ignore', max_df=0.9, ngram_range=(2, 2), 
                             max_features = 20000, stop_words=additional_stopwords)

X = vectorizer.fit_transform(corpus)
X
# Out:
# <500x20000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 762717 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Now we'll do some topic modeling.

# %%
# Initialize NMF
nmf_model = NMF(n_components = 50, solver = 'mu')

# Create variable to make it easy to retrieve topics
idx_to_word = np.array(vectorizer.get_feature_names())

# %%
nmf_model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=50, random_state=None, shuffle=False, solver='mu',
#   tol=0.0001, verbose=0)

# %%
nmf_components = nmf_model.components_

# %%
for i, topic in enumerate(nmf_components):
    print("Topic {}: {}".format(i + 1, ", ".join([str(x) for x in idx_to_word[topic.argsort()[-10:]]])))
# Out:
# Topic 1: gauge theory, nucl phys, string theory, jhep bf, phys bf, begin equation, end equation, arxiv hep, citation hep, hep th
# Topic 2: frac partial, partial partial, right end, equation the, equation frac, equation begin, equation where, equation label, begin equation, end equation
# Topic 3: f_ mu, h_ mu, partial_ mu, nu rho, b_ mu, partial mu, alpha beta, nu mu, a_ mu, mu nu
# Topic 4: hole entropy, the horizon, schwarzschild black, the entropy, of black, s_ bh, gr qc, the black, black holes, black hole
# Topic 5: ee the, lambda_ alpha, in cite, al beta, a_ rm, right ee, rm cr, ee be, ee where, be label
# Topic 6: the plane, hep th, the penrose, bea la, frac mu, penrose limit, light cone, wave background, pp wave, plane wave
# Topic 7: closed strings, the boundary, the tachyon, the open, field theory, the closed, boundary state, open string, string field, closed string
# Topic 8: right rangle_, mathrm exp, ee sigma, u_ mu, displaystyle frac, cite rf, the proton, eq ref, label eq, ref eq
# Topic 9: mathcal mu, www arxiv, end align, begin align, tt hep, http arxiv, href http, abs hep, arxiv org, org abs
# Topic 10: lq lq, theory of, of quantum, the modular, quantum field, local quantum, string theory, quantum gravity, field theory, the emph
# Topic 11: the partition, frac beta, infty frac, pi frac, right label, right right, left right, partition function, frac pi, left frac
# Topic 12: frac bar, sigma mu, psi psi, partial_ bar, psi bar, bar lambda, theta bar, bar psi, bar bar, bar theta
# Topic 13: align where, anharmonic oscillator, non borel, borel summable, variational perturbation, small put, and aut, align label, end align, begin align
# Topic 14: bf nc, bulk scalar, the cosmological, scalar field, the friedmann, extra dimensions, friedmann equation, cosmological constant, the bulk, the brane
# Topic 15: of de, omega ell, the cosmological, the de, on de, kerr de, in de, cosmological horizon, sitter space, de sitter
# Topic 16: sum_ rr, point function, sin pi, point functions, rr rs, c_ 123, pp wave, three point, rm vac, bmn operators
# Topic 17: astro ph, extra dimensions, of inflation, the slow, the extra, the potential, arkani hamed, hep ph, the inflaton, slow roll
# Topic 18: theta theta, left right, right right, em phys, rr left, omega phi, left frac, ln left, frac r_0, r_0 right
# Topic 19: the noncommutative, the wilson, delta theta_d, wilson loop, the gauge, fractional branes, the deconstructed, d3 branes, gauge theory, the orbifold
# Topic 20: phi 2v, big frac, equation noindent, lambda 2n, tilde phi, 4x theta, 2n big, m_i big, qquad qquad, big big
# Topic 21: f_ alpha, bar dot, cal alpha, dot beta, p_ beta, alpha dot, p_ alpha, alpha bar, alpha beta, dot alpha
# Topic 22: the superpotential, rm eff, and vafa, arxiv hep, tr phi, the matrix, effective superpotential, matrix models, w_ rm, matrix model
# Topic 23: type iib, the torsional, radial modulus, calabi yau, heterotic string, bf def, non ahler, three form, cal def, the heterotic
# Topic 24: 12 14, setfigfont 12, 14 rmdefault, color rgb, updefault color, rmdefault mddefault, mddefault updefault, smash setfigfont, makebox lb, lb smash
# Topic 25: gamow vectors, function space, analytic continuation, symplectic transformations, hilbert space, mathscr newcommand, mathfrak sp, semi groups, cap hh, hh 2_
# Topic 26: mu partial_, psi_ phys, ab mu, phi ab, pi mu, phi mu, eta mu, bar psi, mu bar, psi mu
# Topic 27: frac mu, hat gamma, epsilon_ pm, pseudo hermiticity, over hat, tilde tilde, i_ hat, hat phi, gamma hat, hat hat
# Topic 28: al bt, r_1 ldots, bundle to, ldots r_k, the cs, cal newcommand, dr_ la, gs_ 2k, got newcommand, p_ 2k
# Topic 29: l_i phi_i, in cc, calogero moser, hitchin system, the hitchin, spectral curve, space of, end ml, the moduli, moduli space
# Topic 30: tachyon potential, t_ 11, mu nu, bar eta, electric field, 2002 hep, hep th, rolling tachyon, bf _0, the tachyon
# Topic 31: theta cal, ast theta, theta hbar, cal imath, cal ast, theta stackrel, imath theta, cal theta, gamma theta, stackrel circ
# Topic 32: cal _k, classical phase, on cal, cal is, on bf, eqn ref, hilbert space, cal qh, cp cal, bf cp
# Topic 33: delta lambda, tilde mu, star delta, the color, partial_ mu, eqnarray where, a_ mu, eqnarray label, end eqnarray, begin eqnarray
# Topic 34: end widetext, begin widetext, varphi alpha, phi rangle, langle phi, cosmic string, widetext begin, cosmic strings, pi alpha, eq ref
# Topic 35: br symmetry, mathsf bf, chi_ bf, tilde varphi_, u_ bf, phi_ bf, br de, mathfrak def, sl br, cal bf
# Topic 36: the gauge, left handed, topological charge, discrete representations, dirac operator, the sphaleron, gauge potential, dirac hamiltonian, the dirac, spectral flow
# Topic 37: array eqno, sqtwo graph, dag al, del_ xi, del xf, com nn, left begin, array right, end array, begin array
# Topic 38: eeq where, and so, chern kernels, the m5, dirac brane, quantization condition, twisted theory, poisson lie, m5 brane, beq label
# Topic 39: bibnamefont and, bibinfo volume, textbf bibinfo, bibinfo pages, bibinfo journal, bibinfo year, bibitem citenamefont, bibfnamefont bibnamefont, bibinfo author, author bibfnamefont
# Topic 40: begin equation, of ads, fixed point, the cft, the ir, z_ uv, z_ ir, the uv, ir brane, uv brane
# Topic 41: phi equiv, the jacobian, first class, re left, the constraints, on sigma, the constraint, phi approx, phase space, constraint surface
# Topic 42: q_ alpha, brkt frac, dr x_2, tt hep, tl vph, co kp, acl x_2, eq ref, int dr, the wall
# Topic 43: bbb def, cite dowker, begin thm, end thm, and prime, widetilde def, def sst, topology change, handle decomposition, sst def
# Topic 44: cardy states, so 2n, ishibashi states, label eq, tilde lambda, tilde mu, simple current, boundary states, tilde tilde, eqref eq
# Topic 45: and tt, pm j_3, ginsparg wilson, dirac operator, cdot vec, vec sigma, sigma cdot, vec vec, the fuzzy, fuzzy sphere
# Topic 46: with intersecting, standard like, d6 brane, times usp, of d6, intersecting d6, m_p 4d, phantom phantom, times times, d6 branes
# Topic 47: dp brane, string action, world volume, b_1 ldots, the hs, vp sqrt, hs gauge, textbf newcommand, ldots a_, a_1 ldots
# Topic 48: hat al, the c_, left right, eqref eqn, ee noindent, newblock phys, bea label, newblock nucl, ref eqn, label eqn
# Topic 49: inner product, omega g_1, phase factor, ref newcommand, g_1 g_2, the string, discrete torsion, langle rangle, begin displaymath, end displaymath
# Topic 50: pi alpha, in reef, alpha k_1, rm on, on shell, k_1 inn, ga 2t, frac ga, ga ga, pi l_

# %% [markdown]
# These topics are interesting, but we note that a few of them are composed entirely of LaTeX. This is not very interesting, so in order to get more cohesive topics, it's possible that we need to collapse the 50 NMF components into fewer (maybe, for example, 15).
#
# Let's try that next.

# %%
nmf_model_15 = NMF(n_components = 15, solver = 'mu')
nmf_model_15.fit(X)
nmf_components_15 = nmf_model_15.components_

# %%
for i, topic in enumerate(nmf_components_15):
    print("Topic {}: {}".format(i + 1, ", ".join([str(x) for x in idx_to_word[topic.argsort()[-10:]]])))
# Out:
# Topic 1: nucl phys, the brane, gauge theory, phys bf, matrix model, begin equation, end equation, arxiv hep, citation hep, hep th
# Topic 2: mu nu, equation the, equation frac, alpha beta, right end, equation begin, equation where, equation label, begin equation, end equation
# Topic 3: g_ mu, f_ mu, nu rho, partial mu, b_ mu, partial_ mu, nu mu, alpha beta, a_ mu, mu nu
# Topic 4: arxiv gr, schwarzschild black, of black, the horizon, the entropy, s_ bh, gr qc, the black, black holes, black hole
# Topic 5: the space, mathscr newcommand, the lie, hh 2_, there is, bf cp, space of, lie algebra, phase space, hilbert space
# Topic 6: the pp, bmn operators, penrose limit, citation hep, frac mu, light cone, wave background, hep th, pp wave, plane wave
# Topic 7: the boundary, the open, pi alpha, field theory, the closed, the tachyon, boundary state, open string, string field, closed string
# Topic 8: bibitem rf, begin eqnarray, end eqnarray, u_ mu, displaystyle frac, the proton, eq ref, cite rf, label eq, ref eq
# Topic 9: begin align, end align, www arxiv, the brane, tt hep, http arxiv, href http, abs hep, arxiv org, org abs
# Topic 10: lambda_ alpha, a_ rm, a_1 ldots, ee the, rm cr, right ee, label eqn, ee be, ee where, be label
# Topic 11: frac lambda, ln left, pi frac, right right, left right, begin eqnarray, eq ref, end eqnarray, frac pi, left frac
# Topic 12: psi bar, alpha bar, mu bar, psi mu, bar lambda, bar bar, dot alpha, theta bar, bar theta, bar psi
# Topic 13: non borel, label eqn, ref eqn, borel summable, variational perturbation, small put, and aut, align label, end align, begin align
# Topic 14: hat tilde, hat mu, epsilon_ pm, pseudo hermiticity, over hat, i_ hat, tilde tilde, hat phi, gamma hat, hat hat
# Topic 15: scalar field, omega ell, the cosmological, the de, on de, kerr de, in de, cosmological horizon, sitter space, de sitter

# %% [markdown]
# Reducing the number of components seemed to help a bit, but we still have multiple topics that are entirely LaTeX formatting specifications, and the physics-related topics still have some LaTeX artifacts.
#
# Let's turn to LDA and see if it can do any better here.

# %%
lda_model = LatentDirichletAllocation(max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)

lda_model.fit(X)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=50.0,
#              max_doc_update_iter=100, max_iter=5, mean_change_tol=0.001,
#              n_components=10, n_jobs=1, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
for i, topic in enumerate(lda_model.components_):
    print("Topic {}: {}".format(i + 1, ", ".join([str(x) for x in idx_to_word[topic.argsort()[-10:]]])))
# Out:
# Topic 1: to infty, eq ref, alpha beta, end eqnarray, with respect, begin eqnarray, hep th, begin equation, mu nu, end equation
# Topic 2: the orbifold, we can, frac pi, arxiv hep, gauge theory, mu nu, begin equation, citation hep, end equation, hep th
# Topic 3: bar bar, ref eq, plain left, the term, size label, decor size, scs dist, hep th, fmfv decor, fmf plain
# Topic 4: black hole, r_ r_, over sqrt, in cite, mu nu, arxiv hep, end equation, hep th, begin equation, citation hep
# Topic 5: it must, function has, end align, end equation, line in, power spectrum, hep th, def half, ref newcommand, mu nu
# Topic 6: cal imath, hep th, theta cal, begin equation, cal ast, theta stackrel, imath theta, cal theta, gamma theta, stackrel circ
# Topic 7: here the, vspace 5mm, ricci flat, cr bar, bibitem metr, varphi theta, hep th, cmss kern, and corresponding, z_1 z_1
# Topic 8: hermitean metric, wave equation, end equation, obtains begin, _2 hat, dimensional and, the approach, which requires, mu nu, be label
# Topic 9: equation label, fields by, cal supersymmetry, label eq, the deformed, solution this, hat p_2, dot alpha, ref eq, stackrel ab
# Topic 10: left frac, equation label, eq ref, phys bf, arxiv hep, citation hep, mu nu, begin equation, end equation, hep th

# %% [markdown]
# Yikes. LDA didn't do much better. These topics are not especially informative either...
