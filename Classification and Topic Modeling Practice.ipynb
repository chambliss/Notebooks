# %%
import pandas as pd
import numpy as np
import os
from sklearn.feature_extraction.text import *
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %%
filename_list = os.listdir()[0:300]

# %%
# Just making sure these file names are correct:
filename_list[0:5]

# Looks good!
# Out:
# ['0301116', '0304232', '0303017', '0303225', '0302131']

# %% [markdown]
# Now we can read in all the files from the `filename_list`.

# %%
corpus = []

for i in range(len(filename_list)):
    
    filename = filename_list[i]
    
    with open(filename, 'r', errors='ignore') as file:
            file_contents = file.read()
    
    # Add document to corpus
    corpus.append(file_contents)

# %%
len(corpus)
# Out:
# 300

# %% [markdown]
# We have exactly 300 documents to work with. Now we can turn our corpus into a matrix of TF-IDF features using `sklearn`'s `TfidfVectorizer()`.

# %%
vectorizer = TfidfVectorizer(decode_error='ignore', stop_words='english', max_df=0.9, max_features = 10000)

X = vectorizer.fit_transform(corpus)
X
# Out:
# <300x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 286922 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Let's take a look at the vocabulary that was learned by the vectorizer.

# %%
vectorizer.vocabulary_
# Out:
# {'latex': 5619,
#  'file': 4047,
#  'paper': 6902,
#  'documentstyle': 3345,
#  'preprint': 7259,
#  'eqsecnum': 3722,
#  'aps': 1542,
#  'epsfig': 3685,
#  'revtex': 7926,
#  '12pt': 218,
#  'article': 1578,
#  'twocolumn': 9322,
#  'def': 3033,
#  'tt': 9295,
#  'backslash': 1723,
#  'bibtex': 1896,
#  'rm': 7980,
#  'sc': 8147,
#  'ib': 4880,
#  'tex': 9053,
#  'newcommand': 6431,
#  'cs': 2836,
#  'ch': 2270,
#  'beq': 1834,
#  'eeq': 3521,
#  'displaymath': 3294,
#  'beqa': 1835,
#  'eqnarray': 3714,
#  'eeqa': 3522,
#  'partial': 6937,
#  'stackrel': 8615,
#  'leftrightarrow': 5670,
#  'lra': 5856,
#  'ms': 6253,
#  'm_': 5883,
#  'renewcommand': 7813,
#  'thefootnote': 9079,
#  'fnsymbol': 4107,
#  'footnote': 4130,
#  'setcounter': 8272,
#  'alph': 1379,
#  'theequation': 9078,
#  'arabic': 1544,
#  'nn': 6479,
#  'nonumber': 6519,
#  'hbox': 4659,
#  '0pt': 165,
#  'hss': 4807,
#  'original': 6780,
#  'se': 8204,
#  'sa': 8093,
#  'newcounter': 6433,
#  'saveeqn': 8134,
#  'value': 9501,
#  'stepcounter': 8662,
#  'mbox': 6053,
#  'draft': 3395,
#  'flushright': 4101,
#  '02': 48,
#  '03': 114,
#  '11': 186,
#  '01': 20,
#  'title': 9153,
#  'gravity': 4508,
#  'induced': 5020,
#  'smooth': 8475,
#  'soliton': 8490,
#  'author': 1645,
#  'mail': 5930,
#  'edu': 3515,
#  'address': 1269,
#  'center': 2249,
#  'cosmology': 2767,
#  'particle': 6961,
#  'physics': 7088,
#  'department': 3111,
#  'new': 6429,
#  'york': 9903,
#  'university': 9422,
#  'ny': 6609,
#  'date': 2965,
#  'today': 9169,
#  'maketitle': 5947,
#  'consider': 2634,
#  'finite': 4062,
#  'thickness': 9113,
#  'graviton': 4506,
#  'kinetic': 5438,
#  'term': 9042,
#  'coupled': 2786,
#  'bulk': 2085,
#  'scalar': 8148,
#  'develops': 3175,
#  'solitonic': 8491,
#  'vacuum': 9495,
#  'expectation': 3852,
#  'couplings': 2789,
#  'kaluza': 5377,
#  'klein': 5451,
#  'modes': 6189,
#  'localized': 5799,
#  'matter': 6034,
#  'suppressed': 8864,
#  'giving': 4418,
#  'rise': 7973,
#  'distance': 3300,
#  'r_c': 7572,
#  '4d': 843,
#  '5d': 943,
#  'behavior': 1810,
#  'viewed': 9601,
#  'brane': 2036,
#  'regularization': 7758,
#  'model': 6186,
#  'dvali': 3448,
#  'gabadadze': 4278,
#  'porrati': 7200,
#  'newpage': 6438,
#  'worlds': 9779,
#  'theories': 9090,
#  'large': 5609,
#  'infinite': 5032,
#  'extra': 3898,
#  'dimensions': 3247,
#  'recently': 7687,
#  'provided': 7382,
#  'insight': 5072,
#  'number': 6590,
#  'problems': 7309,
#  'high': 4711,
#  'energy': 3634,
#  'possible': 7211,
#  'relations': 7776,
#  'models': 6187,
#  'emerge': 3593,
#  'fundamental': 4238,
#  'higher': 4712,
#  'dimensional': 3242,
#  'described': 3143,
#  'strings': 8692,
#  'realized': 7666,
#  'nature': 6386,
#  'valuable': 9500,
#  'testing': 9049,
#  'ground': 4527,
#  'ideas': 4890,
#  'time': 9145,
#  'believed': 1822,
#  'exist': 3838,
#  'compact': 2506,
#  'volume': 9628,
#  'problem': 7307,
#  'obtain': 6649,
#  'force': 4136,
#  'objects': 6634,
#  'located': 5801,
#  'work': 9771,
#  'cite': 2366,
#  'dgp': 3192,
#  'shown': 8337,
#  'newton': 6442,
#  'arises': 1560,
#  'action': 1248,
#  'label': 5555,
#  'int': 5088,
#  'sqrt': 8588,
#  'cal': 2137,
#  'dy': 3458,
#  'delta': 3076,
#  'r_': 7563,
#  'coordinate': 2731,
#  'dimension': 3241,
#  'curvature': 2861,
#  'g_': 4249,
#  'mn': 6176,
#  'metric': 6109,
#  'r_4': 7568,
#  'constructed': 2667,
#  'mu': 6262,
#  'nu': 6575,
#  'equiv': 3735,
#  'scale': 8150,
#  'm_p': 5902,
#  'characterizes': 2299,
#  'correct': 2742,
#  'constant': 2652,
#  'taken': 8964,
#  'sim': 8377,
#  '10': 168,
#  '19': 296,
#  'gev': 4393,
#  'represented': 7842,
#  'function': 4233,
#  'zero': 9955,
#  'related': 7771,
#  'presented': 7267,
#  'studied': 8705,
#  'phenomenology': 7053,
#  'ref': 7722,
#  'low': 5841,
#  'ev': 3788,
#  'properties': 7363,
#  'cosmological': 2765,
#  'evolution': 3802,
#  'scales': 8153,
#  'string': 8690,
#  'realizations': 7664,
#  'examined': 3812,
#  'str': 8672,
#  'notes': 6548,
#  'study': 8707,
#  'similar': 8379,
#  'enhanced': 3642,
#  'frac': 4169,
#  'chi': 2321,
#  'representing': 7843,
#  'tension': 9035,
#  'linearized': 5745,
#  'level': 5702,
#  'features': 3986,
#  'short': 8328,
#  'metastable': 6105,
#  'massless': 6000,
#  'resonance': 7877,
#  'width': 9741,
#  'distances': 3301,
#  'conclude': 2566,
#  'simpler': 8387,
#  'captures': 2186,
#  'main': 5931,
#  'variation': 9524,
#  'strength': 8680,
#  'consequence': 2628,
#  'dilaton': 3236,
#  'like': 5725,
#  'coupling': 2788,
#  'exhibits': 3837,
#  'vev': 9587,
#  'neglect': 6406,
#  'gravitational': 4503,
#  'effect': 3528,
#  'equivalent': 3738,
#  'fine': 4061,
#  'spectrum': 8548,
#  'lagrangian': 5573,
#  'results': 7902,
#  'applicable': 1519,
#  'gauge': 4320,
#  'investigate': 5175,
#  'suppression': 8865,
#  'kk': 5446,
#  'tunneling': 9304,
#  'potential': 7219,
#  'barrier': 1754,
#  'contrary': 2702,
#  'different': 3219,
#  'scheme': 8163,
#  'considered': 2639,
#  'appendix': 1516,
#  'outline': 6816,
#  'procedure': 7312,
#  'finding': 4058,
#  'fermionic': 4003,
#  'fermion': 4001,
#  'varying': 9549,
#  'localization': 5797,
#  'non': 6495,
#  'homogeneous': 4760,
#  'general': 4347,
#  'let': 5695,
#  'phi': 7055,
#  'x_': 9819,
#  'partial_': 6938,
#  'fields': 4027,
#  'longrightarrow': 5820,
#  'chi_': 2322,
#  'cl': 2378,
#  'represent': 7837,
#  'approximation': 1537,
#  'decompose': 3010,
#  'sum_': 8781,
#  'phi_': 7056,
#  'sigma_': 8353,
#  'box': 2014,
#  'differential': 3221,
#  'wave': 9703,
#  'functions': 4236,
#  'taking': 8966,
#  'equations': 3730,
#  'eigenvalues': 3546,
#  'cross': 2828,
#  'multiplying': 6300,
#  'eigenfunctions': 3541,
#  'subtracting': 8751,
#  'integrating': 5110,
#  'length': 5682,
#  'orthogonality': 6789,
#  'relation': 7774,
#  'alpha_': 1381,
#  'delta_': 3077,
#  'normalization': 6532,
#  'combining': 2481,
#  'negative': 6405,
#  'denominator': 3102,
#  'numerator': 6593,
#  'expression': 3884,
#  'positive': 7204,
#  'means': 6066,
#  'ghosts': 4403,
#  'ghost': 4402,
#  'effective': 3529,
#  'obtained': 6651,
#  'introduce': 5155,
#  'additional': 1266,
#  'charge': 2302,
#  'density': 3109,
#  'psi': 7405,
#  'rho': 7938,
#  'centered': 2250,
#  'coefficient': 2440,
#  'determined': 3167,
#  'profile': 7334,
#  'average': 1661,
#  'tilde': 9142,
#  'reads': 7657,
#  'mode': 6185,
#  'normalizable': 6531,
#  'choices': 2347,
#  'integral': 5104,
#  'single': 8406,
#  'continuum': 2691,
#  'nonzero': 6521,
#  'pm': 7157,
#  'infty': 5045,
#  'feature': 3985,
#  'distinguishes': 3307,
#  'cases': 2205,
#  'quasi': 7535,
#  'determine': 3166,
#  'specify': 8543,
#  'better': 1871,
#  'understand': 9389,
#  'connection': 2623,
#  'shape': 8299,
#  'useful': 9454,
#  'transform': 9225,
#  'schroedinger': 8173,
#  'phi_m': 7068,
#  'quad': 7514,
#  'behave': 1807,
#  'attractive': 1636,
#  'repulsive': 7850,
#  'depends': 3118,
#  'balance': 1736,
#  'magnitude': 5926,
#  'second': 8211,
#  'derivative': 3133,
#  'subsection': 8731,
#  '2a': 573,
#  'lead': 5648,
#  'excitations': 3826,
#  'example': 3814,
#  'gaussian': 4332,
#  'determines': 3168,
#  'tower': 9199,
#  'masses': 5998,
#  'integer': 5100,
#  'used': 9453,
#  'dv': 3444,
#  'repeat': 7824,
#  'use': 9452,
#  'starting': 8635,
#  'point': 7169,
#  'investigation': 5178,
#  'simple': 8386,
#  'harmonic': 4635,
#  'oscillator': 6802,
#  'shifted': 8320,
#  'vanishes': 9507,
#  '2y': 630,
#  'normalized': 6535,
#  'pi': 7091,
#  'ya': 9882,
#  'h_': 4582,
#  'goes': 4451,
#  '2n': 612,
#  'interaction': 5118,
#  'position': 7202,
#  'odd': 6669,
#  'vanishing': 9508,
#  'values': 9503,
#  'true': 9280,
#  'localize': 5798,
#  'reason': 7672,
#  'exponentially': 3876,
#  'decaying': 3004,
#  'doesn': 3349,
#  'naively': 6370,
#  'expect': 3851,
#  'consist': 2642,
#  'scattering': 8155,
#  'states': 8643,
#  'charges': 2304,
#  'q_1': 7470,
#  'q_2': 7472,
#  'exchange': 3821,
#  'change': 2282,
#  'law': 5629,
#  'establish': 3762,
#  'governed': 4468,
#  'quadratically': 7516,
#  'powers': 7225,
#  'pc': 6988,
#  'gets': 4391,
#  'exp': 3843,
#  '3e': 728,
#  'ae': 1310,
#  'bigger': 1905,
#  'huge': 4820,
#  'aa': 1183,
#  'fig': 4030,
#  'vspace': 9650,
#  '5mm': 949,
#  'centerline': 2252,
#  'fig1': 4031,
#  'eps': 3678,
#  '10cm': 181,
#  'footnotesize': 4132,
#  'textbf': 9055,
#  'figure': 4045,
#  'solid': 8489,
#  'line': 5742,
#  'dashed': 2962,
#  'units': 9414,
#  'inverse': 5169,
#  'small': 8461,
#  'coincides': 2450,
#  'certain': 2260,
#  'square': 8591,
#  'cut': 2866,
#  'rapidly': 7626,
#  'drops': 3416,
#  'qualitatively': 7519,
#  'predict': 7244,
#  'lowest': 5848,
#  'bound': 2006,
#  'interested': 5121,
#  'want': 9688,
#  'decay': 3003,
#  'mass': 5997,
#  'irrelevant': 5207,
#  'wkb': 9761,
#  'gamma_': 4291,
#  'int_': 5089,
#  'y_1': 9872,
#  'y_2': 9873,
#  'classical': 2390,
#  'turning': 9308,
#  'points': 7173,
#  'condition': 2583,
#  'validity': 9499,
#  '2v': 627,
#  'll': 5775,
#  'satisfied': 8126,
#  'evaluated': 3791,
#  'numerically': 6595,
#  'range': 7617,
#  'independent': 5005,
#  'behaves': 1809,
#  'power': 7223,
#  'negligible': 6409,
#  'numerical': 6594,
#  'error': 3753,
#  '976': 1079,
#  'continuous': 2689,
#  'solving': 8502,
#  'explore': 3872,
#  'question': 7543,
#  'universality': 9418,
#  'types': 9329,
#  'profiles': 7335,
#  'universal': 9417,
#  'argued': 1555,
#  'fact': 3939,
#  'desirable': 3151,
#  'property': 7364,
#  'opens': 6737,
#  'possibility': 7210,
#  'covariance': 2792,
#  'resulting': 7901,
#  'pointed': 7170,
#  'adopt': 1290,
#  'framework': 4185,
#  'violation': 9612,
#  'forms': 4147,
#  'standard': 8621,
#  'lower': 5843,
#  'cutoff': 2867,
#  'sm': 8459,
#  'particles': 6962,
#  'come': 2482,
#  'splitting': 8573,
#  'roughly': 8023,
#  'psi_': 7406,
#  'decoupled': 3020,
#  'return': 7909,
#  'solved': 8500,
#  'simplicity': 8389,
#  'evaluate': 3790,
#  'qualitative': 7518,
#  'follows': 4120,
#  'outside': 6820,
#  'plane': 7135,
#  'waves': 9709,
#  'frequency': 4202,
#  'inside': 5071,
#  'dependent': 3116,
#  'height': 4672,
#  'approximately': 1535,
#  'approx': 1532,
#  'actual': 1254,
#  'dependence': 3114,
#  'fig2': 4032,
#  'graph': 4490,
#  'positions': 7203,
#  'log': 5806,
#  'plot': 7151,
#  'multiplied': 6295,
#  'responsible': 7886,
#  'starts': 8636,
#  'decays': 3005,
#  'half': 4611,
#  'analysis': 1441,
#  'data': 2964,
#  '005': 15,
#  'resonances': 7878,
#  'particular': 6963,
#  'unusual': 9437,
#  'advocated': 1309,
#  '605': 959,
#  'newtonian': 6443,
#  'mr': 6251,
#  'dm': 3340,
#  'supported': 8858,
#  'gg': 4396,
#  'lightest': 5723,
#  'contribute': 2705,
#  'approximate': 1533,
#  'weak': 9714,
#  'massive': 5999,
#  'gravitons': 4507,
#  'smaller': 8462,
#  'larger': 5611,
#  'reproduce': 7845,
#  'planck': 7133,
#  'rc': 7641,
#  'spin': 8560,
#  'gives': 4417,
#  'wrong': 9800,
#  'tensor': 9038,
#  'structure': 8701,
#  'propagator': 7359,
#  'va': 9490,
#  'linear': 5743,
#  'effects': 3531,
#  'conjecture': 2611,
#  'mechanism': 6076,
#  'occurs': 6662,
#  'hand': 4623,
#  'currently': 2857,
#  'progress': 7340,
#  '1cm': 382,
#  'acknowledgments': 1238,
#  'thank': 9075,
#  'alex': 1355,
#  'vilenkin': 9605,
#  'comments': 2489,
#  'grateful': 4497,
#  'discussion': 3283,
#  'encouraging': 3621,
#  'make': 5940,
#  'manuscript': 5967,
#  '2in': 600,
#  'method': 6106,
#  'fermions': 4004,
#  'xf': 9844,
#  'bar': 1745,
#  'dirac': 3257,
#  'algebra': 1360,
#  'gamma': 4290,
#  '2g': 595,
#  'ab': 1185,
#  'choice': 2346,
#  'matrices': 6031,
#  'motion': 6228,
#  'ansatz': 1472,
#  'g_m': 4265,
#  'xi_': 9846,
#  'h_m': 4597,
#  '2mm': 609,
#  'spinors': 8565,
#  'spinor': 8563,
#  'a_m': 1174,
#  'sin': 8400,
#  'b_m': 1706,
#  'cos': 2759,
#  'plugging': 7154,
#  'f_': 3917,
#  'rlap': 7978,
#  'matrix': 6032,
#  'fourier': 4165,
#  'ft': 4215,
#  'clearly': 2397,
#  'reduced': 7712,
#  'diagonalization': 3199,
#  'hermitian': 4690,
#  'steps': 8663,
#  'write': 9793,
#  'schematically': 8162,
#  'dagger': 2948,
#  'lambda_': 5579,
#  'rotated': 8014,
#  'orthogonal': 6788,
#  'chosen': 2352,
#  'diagonalize': 3200,
#  'simplest': 8388,
#  'recover': 7696,
#  'ordinary': 6768,
#  'entry': 3665,
#  'entries': 3663,
#  'diagonal': 3198,
#  'upper': 9443,
#  'corner': 2739,
#  'column': 2470,
#  'row': 8028,
#  'zeroes': 9956,
#  'propagating': 7357,
#  'interesting': 5122,
#  'compare': 2515,
#  'references': 7727,
#  'bibitem': 1893,
#  'minkowski': 6152,
#  'lett': 5697,
#  '208': 455,
#  '2000': 406,
#  'hep': 4685,
#  'gregory': 4518,
#  'rubakov': 8049,
#  'opening': 6735,
#  'ultra': 9362,
#  'rev': 7912,
#  '84': 1045,
#  'arxiv': 1580,
#  'csaki': 2838,
#  'erlich': 3750,
#  'hollowood': 4749,
#  '64': 980,
#  '2001': 410,
#  'ph': 7045,
#  'citation': 2365,
#  '65': 988,
#  '2002': 416,
#  'lykken': 5875,
#  'pokorski': 7176,
#  'scenarios': 8157,
#  'nucl': 6583,
#  '609': 962,
#  'deffayet': 3037,
#  '502': 874,
#  '199': 348,
#  'acta': 1246,
#  '32': 653,
#  'accelerated': 1210,
#  'universe': 9419,
#  'astro': 1606,
#  'ds': 3419,
#  'jhep': 5289,
#  '0108': 30,
#  '034': 122,
#  'poppitz': 7198,
#  'casimir': 2206,
#  'radius': 7599,
#  'stabilization': 8607,
#  'orbifolds': 6760,
#  '0106': 26,
#  '019': 46,
#  'conductor': 2586,
#  'black': 1938,
#  'hole': 4745,
#  'solutions': 8496,
#  'braneworlds': 2040,
#  '66': 991,
#  'siopsis': 8416,
#  'fat': 3973,
#  'branes': 2038,
#  'discontinuity': 3271,
#  'vainshtein': 9497,
#  'nonperturbative': 6509,
#  'continuity': 2688,
#  'versus': 9581,
#  'perturbative': 7032,
#  'cosmic': 2764,
#  'world': 9776,
#  'fully': 4231,
#  'covariant': 2793,
#  'van': 9505,
#  'dam': 2950,
#  'veltman': 9567,
#  'zakharov': 9940,
#  'absence': 1200,
#  'thereof': 9093,
#  'probing': 7306,
#  'dark': 2959,
#  'using': 9457,
#  'local': 5793,
#  'lowe': 5842,
#  'ramgoolam': 7610,
#  'einstein': 3549,
#  'hilbert': 4717,
#  '0107': 28,
#  '030': 115,
#  'antoniadis': 1500,
#  'minasian': 6140,
#  'calabi': 2138,
#  'yau': 9887,
#  'manifolds': 5962,
#  '69': 1004,
#  '2003': 450,
#  'kiritsis': 5441,
#  '012': 38,
#  'annihilation': 1464,
#  'dubovsky': 3437,
#  'equivalence': 3736,
#  'principle': 7295,
#  'add': 1261,
#  'arkani': 1562,
#  'hamed': 4617,
#  'dimopoulos': 3248,
#  '263': 524,
#  '1998': 363,
#  '257': 513,
#  'd59': 2905,
#  '1999': 369,
#  'yang': 9884,
#  'mills': 6134,
#  '22': 470,
#  '397': 716,
#  '1970': 324,
#  'nonvanishing': 6520,
#  'gravitation': 4502,
#  '39': 711,
#  '393': 713,
#  '1972': 326,
#  'preparation': 7257,
#  'yu': 9908,
#  'smirnov': 8471,
#  'photon': 7079,
#  '535': 898,
#  '295': 559,
#  'documentclass': 3344,
#  'usepackage': 9455,
#  'graphics': 4491,
#  'color': 2467,
#  'amsmath': 1425,
#  'amssymb': 1426,
#  'da': 2938,
#  'dot': 3371,
#  'alpha': 1380,
#  'db': 2973,
#  'beta': 1853,
#  'dg': 3186,
#  'dd': 2984,
#  'lambda': 5578,
#  'sigma': 8352,
#  'varepsilon': 9513,
#  'tr': 9209,
#  'tau': 8979,
#  'omega': 6698,
#  'varrho': 9545,
#  'vt': 9651,
#  'vartheta': 9547,
#  'mc': 6056,
#  'mathcal': 6014,
#  'nabla': 6353,
#  'la': 5544,
#  'langle': 5603,
#  'ra': 7584,
#  'rangle': 7619,
#  'dag': 2945,
#  'wt': 9804,
#  'widetilde': 9740,
#  'tb': 8994,
#  'lr': 5855,
#  'numberwithin': 6592,
#  'setlength': 8275,
#  'textwidth': 9065,
#  '17cm': 285,
#  'textheight': 9058,
#  '22cm': 480,
#  'topmargin': 9182,
#  '0mm': 163,
#  'evensidemargin': 3795,
#  'oddsidemargin': 6671,
#  'parskip': 6935,
#  'baselinestretch': 1765,
#  '2pt': 619,
#  'zop': 9987,
#  'sf': 8286,
#  'rr': 8038,
#  'thispagestyle': 9123,
#  'addtocounter': 1273,
#  'page': 6883,
#  'aei': 1312,
#  '040': 130,
#  'vskip': 9648,
#  '5cm': 942,
#  'alternative': 1400,
#  'formulation': 4154,
#  'light': 5721,
#  'cone': 2587,
#  '0cm': 156,
#  'pankiewicz': 6899,
#  'max': 6040,
#  'institut': 5084,
#  'ur': 9446,
#  'germany': 4388,
#  'april': 1541,
#  'noindent': 6489,
#  'construct': 2666,
#  'manifestly': 5959,
#  'times': 9148,
#  'invariant': 5166,
#  'supersymmetric': 8849,
#  'extension': 3891,
#  'closed': 2406,
#  'cubic': 2848,
#  'vertex': 9584,
#  'dynamical': 3460,
#  'supercharges': 8815,
#  'built': 2084,
#  'bosonic': 1997,
#  'creation': 2818,
#  'oscillators': 6803,
#  'previously': 7284,
#  'formalism': 4141,
#  'formulations': 4155,
#  'physically': 7086,
#  'evidence': 3799,
#  'claim': 2380,
#  'discrete': 3277,
#  'zop_2': 9988,
#  'symmetry': 8906,
#  'computing': 2554,
#  'shift': 8319,
#  'stringy': 8693,
#  'state': 8639,
#  'perturbation': 7030,
#  'verify': 9574,
#  'leading': 5649,
#  'planar': 7132,
#  'correction': 2744,
#  'anomalous': 1470,
#  'dual': 3429,
#  'operators': 6742,
#  'correctly': 2746,
#  'recovered': 7697,
#  'vfill': 9591,
#  'thesection': 9098,
#  'maximally': 6043,
#  'pp': 7226,
#  'blau': 1943,
#  'henceforth': 4682,
#  'referred': 7728,
#  'split': 8571,
#  '2dx': 587,
#  'dx': 3451,
#  'vec': 9559,
#  'bigl': 1908,
#  'bigr': 1910,
#  'f_5': 3923,
#  'wedge': 9719,
#  'provides': 7384,
#  'tractable': 9218,
#  'curved': 2864,
#  'background': 1719,
#  'flux': 4102,
#  'aspects': 1590,
#  'type': 9328,
#  'iib': 4917,
#  'green': 4515,
#  'schwarz': 8177,
#  'sheet': 8311,
#  'quadratic': 7515,
#  'quantized': 7528,
#  'exactly': 3809,
#  'metsaev': 6111,
#  '2001bj': 412,
#  'consists': 2647,
#  'unique': 9406,
#  'excited': 3827,
#  '2002re': 437,
#  'qquad': 7509,
#  'momentum': 6206,
#  'important': 4962,
#  'aspect': 1589,
#  'penrose': 6998,
#  'limit': 5730,
#  'gueven': 4561,
#  'ads_5': 1298,
#  'berenstein': 1839,
#  '2002jq': 431,
#  'allowed': 1374,
#  'derive': 3135,
#  'duality': 3431,
#  'double': 3377,
#  'scaling': 8154,
#  'su': 8712,
#  'super': 8810,
#  'sym': 8896,
#  'ads': 1293,
#  'cft': 2265,
#  'correspondence': 2754,
#  'maldacena': 5951,
#  'gubser': 4558,
#  '1998bc': 365,
#  'witten': 9757,
#  '1998qj': 367,
#  'albeit': 1350,
#  'special': 8535,
#  'supergravity': 8829,
#  'solvability': 8497,
#  'induces': 5021,
#  'parameters': 6919,
#  '2_': 563,
#  'text': 9054,
#  'ym': 9901,
#  'g_2': 4252,
#  'conformal': 2601,
#  '_r': 1127,
#  'subgroup': 8720,
#  'corresponding': 2756,
#  'singled': 8407,
#  'composite': 2543,
#  'bmn': 1956,
#  'difference': 3217,
#  'remains': 7795,
#  'fixed': 4075,
#  'duals': 3435,
#  'quantity': 7525,
#  'gross': 4524,
#  'santambrogio': 8122,
#  '2002sb': 439,
#  'genus': 4370,
#  'counting': 2783,
#  'parameter': 6913,
#  'kristjansen': 5498,
#  '2002bb': 420,
#  'constable': 2649,
#  'subsequently': 8735,
#  'novel': 6555,
#  'extensively': 3894,
#  'beisert': 1815,
#  'gursoy': 4568,
#  'janik': 5281,
#  '2002tn': 444,
#  'minahan': 6139,
#  '2002ff': 428,
#  'klose': 5455,
#  'interactions': 5119,
#  'correspond': 2753,
#  'sector': 8218,
#  'interacting': 5117,
#  'cf': 2262,
#  'eqref': 3720,
#  'flat': 4080,
#  'operator': 6740,
#  'approach': 1526,
#  'difficulties': 3229,
#  'associated': 1596,
#  'transverse': 9248,
#  'coordinates': 2732,
#  'exploiting': 3870,
#  'lorentz': 5830,
#  'broken': 2065,
#  'generator': 4365,
#  'involved': 5184,
#  'developed': 3172,
#  'mandelstam': 5955,
#  'cremmer': 2820,
#  'extended': 3888,
#  'superstring': 8847,
#  'successfully': 8757,
#  'generalized': 4355,
#  'spradlin': 8579,
#  '2002ar': 418,
#  '2002rv': 438,
#  '2002tg': 443,
#  'klebanov': 5450,
#  'open': 6734,
#  'chandrasekhar': 2280,
#  ...}

# %% [markdown]
# As we can see, a -lot- of the vocabulary learned by the vectorizer has to do with LaTeX formatting for these papers.

# %%
# Initialize NMF
nmf_model = NMF(n_components = 50, solver = 'mu')

# Create variable to make it easy to retrieve topics
idx_to_word = np.array(vectorizer.get_feature_names())

# %%
nmf_model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=50, random_state=None, shuffle=False, solver='mu',
#   tol=0.0001, verbose=0)

# %%
nmf_components = nmf_model.components_

# %%
for i, topic in enumerate(nmf_components):
    print("Topic {}: {}".format(i + 1, ", ".join([str(x) for x in idx_to_word[topic.argsort()[-10:]]])))
# Out:
# Topic 1: label, a_, alpha, rho, eqnarray, gauge, partial_, frac, nu, mu
# Topic 2: gauge, phi, nolimits, cr, string, hbox, hep, rm, lref, def
# Topic 3: columncolor, sigma, pm, mid, cr, delta, partial_, wznw, chi, bar
# Topic 4: quad, pm, tau, _1, ast, hbar, label, array, frac, psi
# Topic 5: quad, phi_, sitter, ref, gamma, ee, fuzzy, 2k, tilde, hat
# Topic 6: temperature, xi, beta, noncommutative, eff, bm, ref, infty, pi, frac
# Topic 7: gamma_1, gamma, eqn, psi, gamma_, cr, cdot, pm, underline, vec
# Topic 8: spacetime, ref, frac, metric, hole, ds, r_, black, ell, horizon
# Topic 9: radim, wedge, bibitem, star, theta, cite, label, ref, ee, eq
# Topic 10: alpha, epsilon, pi, cal, arxiv, eqalign, superpotential, cr, lref, eqn
# Topic 11: action, supergravity, d3, sqrt, label, gamma, bulk, frac, branes, brane
# Topic 12: radiation, cite, born, infeld, dot, bibitem, universe, density, rho_, inflation
# Topic 13: textrm, lambda, waldmann, frac, textbf, star, mathbb, emph, newblock, mathcal
# Topic 14: rangle, spin, m_, cite, label, ref, string, gamma, beta, alpha
# Topic 15: wall, tht_1, kp, acl, ee, tht_2, brkt, vph, eql, x_2
# Topic 16: chart, hilbert, holomorphic, fibre, bundles, rm, qh, bundle, cp, cal
# Topic 17: w_, scft, gauge, su, 2n_f, superpotential, monopoles, flavor, n_c, n_f
# Topic 18: ti, qq, bar, chi, tht, bx, eref, cal, eeq, beq
# Topic 19: tt, kappa_5, cite, citation, http, hep, abs, href, org, arxiv
# Topic 20: aligned, rho_c, dot, algebra, frac, alignat, gamma_, text, rho, big
# Topic 21: item, pi_3, lcl, 1n, array, noncommutative, x_i, sphere, fuzzy, eqno
# Topic 22: v_, bracket, 2n, pb, nb, cdots, c_, sigma_, a_, footnotesize
# Topic 23: gamma, susy, boundary, noncommutative, pi, overline, rm, newcommand, ast, theta
# Topic 24: m_, dot, pl_5, si, gb, xf, la, ga, al, newcommand
# Topic 25: instability, charge, flux, newblock, 9cm, core, figure, cheshire, monopole, alice
# Topic 26: big, lambda_j, lambda_2, nu_a, lambda_k, mu_k, prod_, lambda_, hbar, lambda
# Topic 27: m_z, mathbb, m_u, 3v, holonomy, mo, ar, times, ti, su
# Topic 28: p_1, gso, inn, p_2, k_1, z_i, ring, k_2, reef, tachyon
# Topic 29: mut, bigr, bigl, _n, eqnarray, x_0, eq, sigma, tau, tilde
# Topic 30: clifford, k_, gamma, omega_, epsilon_, cd, abcd, sp, stackrel, ab
# Topic 31: domain, hep, cite, parent, gluodynamics, citation, daughter, orientifold, walls, wall
# Topic 32: pi, vortices, gauge, label, tau, matrix, cite, phi, ref, curve
# Topic 33: operators, vac, impurities, kappa, co_, eqlabel, def, psfrag, bmn, eqref
# Topic 34: cc, hz, cb, bea, eea, z_, bref, hj, gam, hi
# Topic 35: spacetime, gibbons, nu, rosen, bbb, bigr, bigl, tachyon, ben, een
# Topic 36: overline, models, branes, n_a, phantom, orientifold, times, hline, d6, def
# Topic 37: 0_2, text, cjt, nd0, p_, emph, nu, overline, chi, varphi
# Topic 38: actions, h_, action, nabla, rm, ee, parent, nabla_, kl, ij
# Topic 39: approx, textbf, tunneling, i_3, hbar, bibitem, emph, cite, jordan, phi
# Topic 40: rpf, w_6, twisted, cohomology, brane, o4, wedge, newcommand, ensuremath, g_4
# Topic 41: fp, kleinert, frac, var, variational, label, summable, borel, aut, align
# Topic 42: abj, polarization, torsion, kern, relax, llap, raise0, kern0, 17ex, 15em
# Topic 43: branecolor, 618033989, linewidth, pscircle, l_, psline, psset, boundary, rput, linecolor
# Topic 44: snp, superpotential, li, elliptic, ls, ttau, theta_1, ln, ep, tfrac
# Topic 45: cite, frequencies, quantum, holes, area, gr, quasinormal, qc, hole, black
# Topic 46: ghost, branes, cq_f, ket, open, pi, hep, citation, closed, string
# Topic 47: f_, n_b, algebras, affine, f_i, leq, algebra, b_, n_, u_q
# Topic 48: hopf, torsion, phi_3, soliton, psi_0, g_x, vphi, lrcorner, solitons, psi_3
# Topic 49: handles, varepsilon, bz, topology, handle, pa, surgery, thm, cobordism, prime
# Topic 50: noncommutative, 00, gg_, equ, ubar, setfigfont, ui, rep, definecolor, rgb

# %% [markdown]
# Sadly, these topics are not very coherent. We can spot a few that do seem to form a cohesive group, such as topic 14, which corresponds to figure-and-display-related LaTeX terms, and 23, which is similar. Quite a few individual topics seem to correspond to symbols and Greek letters. One question I have following this is why some of these would not simply be in the same category. It's possible that 50 components is too many, considering we've only read in 25 papers, and that we need to collapse the 50 NMF components into fewer (maybe, for example, 10).
#
# Let's try that next.

# %%
nmf_model_10 = NMF(n_components = 10, solver = 'mu')
nmf_model_10.fit(X)
nmf_components_10 = nmf_model_10.components_

# %%
for i, topic in enumerate(nmf_components_10):
    print("Topic {}: {}".format(i + 1, ", ".join([str(x) for x in idx_to_word[topic.argsort()[-10:]]])))
# Out:
# Topic 1: alpha, hep, phi, bibitem, brane, ref, label, mu, cite, frac
# Topic 2: arxiv, hbox, gauge, branes, rm, citation, lref, string, hep, def
# Topic 3: f_, tilde, ab, psi, a_, partial_, bar, alpha, nu, mu
# Topic 4: tau, array, sigma, gamma, tilde, pm, frac, theta, psi, bar
# Topic 5: ref, quad, gamma, sphere, 2k, ee, fuzzy, tilde, big, hat
# Topic 6: p_, varphi, noncommutative, infty, ref, beta, prime, lambda, pi, frac
# Topic 7: a_, big, cdot, gamma_, cr, eqn, pm, underline, psi, vec
# Topic 8: qc, area, entropy, ell, r_, holes, ee, horizon, hole, black
# Topic 9: bibitem, eq, newcommand, label, cite, rm, ee, ref, mathcal, cal
# Topic 10: wedge, superpotential, cr, cal, lambda, big, lref, beta, alpha, eqn

# %% [markdown]
# Hmm. Reducing the number of components (and experimenting with changing the solver) did not seem to help. Now our components are even less informative, as they are now overtaken completely by the LaTeX specifications.
#
# Let's turn to LDA and see if it can do any better here.

# %%
lda_model = LatentDirichletAllocation(max_iter = 5,
                                learning_method = 'online',
                                learning_offset = 50.,
                                random_state = 0)

lda_model.fit(X)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=50.0,
#              max_doc_update_iter=100, max_iter=5, mean_change_tol=0.001,
#              n_components=10, n_jobs=1, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
for i, topic in enumerate(lda_model.components_):
    print("Topic {}: {}".format(i + 1, ", ".join([str(x) for x in idx_to_word[topic.argsort()[-20:]]])))
# Out:
# Topic 1: martelli, gather, varepsilon, fluids, frac, phi, financial, lambda, bachas, polarizations, vardi, mu, citation, took, need, bibitem, massive, balasubramanian, rev, eq
# Topic 2: footnotesize, suffers, mathcal, 562, 0211198, kl, psi_l, collaboration, 64, 353, 20pt, 570, label, m_d, chebyshev, zf, frac, wetterich, d2, mu
# Topic 3: nu, bcirc_, fluxes, irp, 0i, subject, trap, cite, brane, cal, succeed, l_, ref, mu, def, rm, label, bar, theta, frac
# Topic 4: mu, observe, cascade, tri, relationships, statistics, lambda_m, favor, oint_, n_c, antighost, 387, electronic, partial, enjoys, bdd, quantisation, bootstrap, alice, evolving
# Topic 5: xm, schemes, doteqdot, worldsheet, 9711200, 633, distinction, u_r, 9905221, dissipation, symmetrized, 543, louis, eqno, d19, limited, metr, serve, sign, matrix
# Topic 6: uni, bea, i_0, holography, tb, forms, 2001af, 8cm, renormalizability, n_g, lattice, gh, 9711200, textit, tqft, toroidal, nonumber, frac, mu, prd
# Topic 7: ee, psi, string, pi, lambda, rm, hep, hat, cal, nu, bibitem, phi, bar, alpha, label, def, cite, ref, mu, frac
# Topic 8: localized, ads_3, eq4, michela, x_a, marotta, couples, poles, riemannian, ar, superspaces, compactification, 458, skiba, hat, worldsheets, affleck, eq10, oz, big
# Topic 9: divecchia, kibble, multiplets, mathbf, hikida, lifted, 1997ep, q_c, 1996sw, introducing, producing, as90, nabla, n_, alpha, nicely, tell, peq, wh, guiding
# Topic 10: r_, reference, context, article, 315, vfill, cft, mathbb, certain, eff, bundle, dualizing, sugra, encountered, kappa, ar, centerline, ref, frac, def
